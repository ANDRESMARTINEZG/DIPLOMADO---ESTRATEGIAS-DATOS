# %%
import pandas as pd
import requests
import os

# %%
api_url = "https://www.datos.gov.co/resource/nudc-7mev.json?$limit=50000"
print(f"📥 Extrayendo datos desde: {api_url}")

try:
    response = requests.get(api_url)
    response.raise_for_status()  # Lanza un error si la petición falla (ej: 404)
    data = response.json()
    df_raw = pd.DataFrame(data)
    print(f"✅ ¡Extracción exitosa! Se cargaron {len(df_raw)} filas.")
    display(df_raw.head())

except requests.exceptions.RequestException as e:
    print(f"❌ Error al extraer los datos: {e}")
    df_raw = pd.DataFrame() # Creamos un dataframe vacío para evitar errores posteriores

except Exception as e:
    print(f"❌ Ocurrió un error inesperado: {e}")
    df_raw = pd.DataFrame()
# Out:
# 📥 Extrayendo datos desde: https://www.datos.gov.co/resource/nudc-7mev.json?$limit=50000
# ✅ ¡Extracción exitosa! Se cargaron 14585 filas.
#     a_o c_digo_municipio   municipio c_digo_departamento departamento  \
# 0  2023            05004    Abriaquí                  05    Antioquia
# 1  2023            95025  El Retorno                  95     Guaviare
# 2  2023            95200  Miraflores                  95     Guaviare
# 3  2023            97001        Mitú                  97       Vaupés
# 4  2023            97161      Caruru                  97       Vaupés
#
#   c_digo_etc              etc poblaci_n_5_16 tasa_matriculaci_n_5_16  \
# 0       3758  Antioquia (ETC)            503                   62.62
# 1       3830   Guaviare (ETC)           4438                   53.27
# 2       3830   Guaviare (ETC)           2014                   32.52
# 3       3831     Vaupés (ETC)          10986                   59.57
# 4       3831     Vaupés (ETC)           1228                    51.3
#
#   cobertura_neta  ... reprobaci_n_primaria reprobaci_n_secundaria  \
# 0          62.62  ...                 1.96                  16.51
# 1          53.27  ...                 7.11                   9.39
# 2          32.52  ...                 6.93                  14.13
# 3          59.57  ...                 4.04                   8.33
# 4           51.3  ...                 7.32                  15.28
#
#   reprobaci_n_media repitencia repitencia_transici_n repitencia_primaria  \
# 0              2.04       9.52                     0               10.46
# 1              1.75       9.34                  6.95               11.84
# 2              7.81       8.65                  6.67                9.04
# 3               4.6      16.18                  7.75               21.04
# 4              7.27       9.24                  2.86                7.62
#
#   repitencia_secundaria repitencia_media tama_o_promedio_de_grupo  \
# 0                 13.76             2.04                      NaN
# 1                  8.48             3.16                      NaN
# 2                 10.25             1.54                      NaN
# 3                 13.84             7.18                      NaN
# 4                 14.85             3.64                      NaN
#
#   sedes_conectadas_a_internet
# 0                         NaN
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                         NaN
#
# [5 rows x 41 columns]

# %% [markdown]
# ## Aprendiendo Pandas

# %%
df_raw.info() ## ver información general de la base
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14585 entries, 0 to 14584
# Data columns (total 41 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   a_o                          14585 non-null  object
#  1   c_digo_municipio             14585 non-null  object
#  2   municipio                    14585 non-null  object
#  3   c_digo_departamento          14585 non-null  object
#  4   departamento                 14585 non-null  object
#  5   c_digo_etc                   14585 non-null  object
#  6   etc                          14585 non-null  object
#  7   poblaci_n_5_16               14579 non-null  object
#  8   tasa_matriculaci_n_5_16      14470 non-null  object
#  9   cobertura_neta               14474 non-null  object
#  10  cobertura_neta_transici_n    14533 non-null  object
#  11  cobertura_neta_primaria      14494 non-null  object
#  12  cobertura_neta_secundaria    14491 non-null  object
#  13  cobertura_neta_media         14492 non-null  object
#  14  cobertura_bruta              14517 non-null  object
#  15  cobertura_bruta_transici_n   14488 non-null  object
#  16  cobertura_bruta_primaria     14504 non-null  object
#  17  cobertura_bruta_secundaria   14497 non-null  object
#  18  cobertura_bruta_media        14458 non-null  object
#  19  deserci_n                    14443 non-null  object
#  20  deserci_n_transici_n         13682 non-null  object
#  21  deserci_n_primaria           14343 non-null  object
#  22  deserci_n_secundaria         14315 non-null  object
#  23  deserci_n_media              13851 non-null  object
#  24  aprobaci_n                   14560 non-null  object
#  25  aprobaci_n_transici_n        14492 non-null  object
#  26  aprobaci_n_primaria          14560 non-null  object
#  27  aprobaci_n_secundaria        14531 non-null  object
#  28  aprobaci_n_media             14484 non-null  object
#  29  reprobaci_n                  14499 non-null  object
#  30  reprobaci_n_transici_n       14492 non-null  object
#  31  reprobaci_n_primaria         14488 non-null  object
#  32  reprobaci_n_secundaria       14479 non-null  object
#  33  reprobaci_n_media            14440 non-null  object
#  34  repitencia                   14442 non-null  object
#  35  repitencia_transici_n        14426 non-null  object
#  36  repitencia_primaria          14437 non-null  object
#  37  repitencia_secundaria        14433 non-null  object
#  38  repitencia_media             14446 non-null  object
#  39  tama_o_promedio_de_grupo     7572 non-null   object
#  40  sedes_conectadas_a_internet  7768 non-null   object
# dtypes: object(41)
# memory usage: 4.6+ MB

# %% [markdown]
# Generemos una "muestra" de conjunto de datos
# 1. Tomando los primeros registros del conjunto de datos.

# %%
df_raw.head(15) ## metodo
# Out:
#      a_o c_digo_municipio              municipio c_digo_departamento  \
# 0   2023            05004               Abriaquí                  05
# 1   2023            95025             El Retorno                  95
# 2   2023            95200             Miraflores                  95
# 3   2023            97001                   Mitú                  97
# 4   2023            97161                 Caruru                  97
# 5   2023            97511                  Pacoa                  97
# 6   2023            97666                Taraira                  97
# 7   2023            97777               Papunaua                  97
# 8   2023            97889               Yavaraté                  97
# 9   2023            99001         Puerto Carreño                  99
# 10  2023            99524           La Primavera                  99
# 11  2023            99624          Santa Rosalía                  99
# 12  2023            99773               Cumaribo                  99
# 13  2023            95001  San José del Guaviare                  95
# 14  2023            94887              Pana Pana                  94
#
#    departamento c_digo_etc              etc poblaci_n_5_16  \
# 0     Antioquia       3758  Antioquia (ETC)            503
# 1      Guaviare       3830   Guaviare (ETC)           4438
# 2      Guaviare       3830   Guaviare (ETC)           2014
# 3        Vaupés       3831     Vaupés (ETC)          10986
# 4        Vaupés       3831     Vaupés (ETC)           1228
# 5        Vaupés       3831     Vaupés (ETC)           1678
# 6        Vaupés       3831     Vaupés (ETC)            814
# 7        Vaupés       3831     Vaupés (ETC)            209
# 8        Vaupés       3831     Vaupés (ETC)            561
# 9       Vichada       3832    Vichada (ETC)           4641
# 10      Vichada       3832    Vichada (ETC)           2659
# 11      Vichada       3832    Vichada (ETC)           1159
# 12      Vichada       3832    Vichada (ETC)          25357
# 13     Guaviare       3830   Guaviare (ETC)          13980
# 14      Guainía       3829    Guainía (ETC)            718
#
#    tasa_matriculaci_n_5_16 cobertura_neta  ... reprobaci_n_primaria  \
# 0                    62.62          62.62  ...                 1.96
# 1                    53.27          53.27  ...                 7.11
# 2                    32.52          32.52  ...                 6.93
# 3                    59.57          59.57  ...                 4.04
# 4                     51.3           51.3  ...                 7.32
# 5                    54.29          54.29  ...                    0
# 6                     22.6           22.6  ...                    0
# 7                        0              0  ...                    0
# 8                    47.95          47.95  ...                    0
# 9                   144.52         144.52  ...                12.96
# 10                   95.94          95.94  ...                13.46
# 11                   83.87          83.87  ...                 7.69
# 12                   49.85          49.85  ...                21.35
# 13                   90.57          90.54  ...                 6.84
# 14                   37.33          37.33  ...                 6.57
#
#    reprobaci_n_secundaria reprobaci_n_media repitencia repitencia_transici_n  \
# 0                   16.51              2.04       9.52                     0
# 1                    9.39              1.75       9.34                  6.95
# 2                   14.13              7.81       8.65                  6.67
# 3                    8.33               4.6      16.18                  7.75
# 4                   15.28              7.27       9.24                  2.86
# 5                       0                 0      23.21                 25.86
# 6                       0                 0      21.58                 13.33
# 7                       0                 0          0                     0
# 8                       0                 0      12.33                  3.13
# 9                   18.84              8.81      11.18                  0.82
# 10                   8.91               4.8      13.98                  1.55
# 11                  17.89              2.83      13.99                     0
# 12                   9.87              5.13      21.27                  0.52
# 13                  15.69              5.67      10.84                  6.83
# 14                  18.75                 0      31.37                     0
#
#    repitencia_primaria repitencia_secundaria repitencia_media  \
# 0                10.46                 13.76             2.04
# 1                11.84                  8.48             3.16
# 2                 9.04                 10.25             1.54
# 3                21.04                 13.84             7.18
# 4                 7.62                 14.85             3.64
# 5                 30.3                 14.25             6.59
# 6                22.29                     0                0
# 7                    0                     0                0
# 8                 19.5                  3.95                4
# 9                13.25                 10.45             6.39
# 10               19.37                  11.8             1.48
# 11               16.48                 17.01             2.83
# 12               27.83                 11.87             6.56
# 13               11.44                 13.61             1.92
# 14               42.93                 18.75             6.67
#
#    tama_o_promedio_de_grupo sedes_conectadas_a_internet
# 0                       NaN                         NaN
# 1                       NaN                         NaN
# 2                       NaN                         NaN
# 3                       NaN                         NaN
# 4                       NaN                         NaN
# 5                       NaN                         NaN
# 6                       NaN                         NaN
# 7                       NaN                         NaN
# 8                       NaN                         NaN
# 9                       NaN                         NaN
# 10                      NaN                         NaN
# 11                      NaN                         NaN
# 12                      NaN                         NaN
# 13                      NaN                         NaN
# 14                      NaN                         NaN
#
# [15 rows x 41 columns]

# %% [markdown]
# 2. Ahora, usamos los índices para mostrar una fracción del conjunto de datos.

# %%
df_raw.iloc[20:30] # (ver de 20 al 30) Pensemos en estos indices como un intervalo semiabierto [20,30)
# Out:
#      a_o c_digo_municipio         municipio c_digo_departamento departamento  \
# 20  2023            94001           Inírida                  94      Guainía
# 21  2023            91798          Tarapacá                  91     Amazonas
# 22  2023            91669  Puerto Santander                  91     Amazonas
# 23  2023            91540     Puerto Nariño                  91     Amazonas
# 24  2023            91536      Puerto Arica                  91     Amazonas
# 25  2023            91530    Puerto Alegría                  91     Amazonas
# 26  2023            91460   Miriti - Paraná                  91     Amazonas
# 27  2023            91430       La Victoria                  91     Amazonas
# 28  2023            91407        La Pedrera                  91     Amazonas
# 29  2023            91405       La Chorrera                  91     Amazonas
#
#    c_digo_etc             etc poblaci_n_5_16 tasa_matriculaci_n_5_16  \
# 20       3829   Guainía (ETC)           9673                   77.42
# 21       3828  Amazonas (ETC)           1327                   50.04
# 22       3828  Amazonas (ETC)            618                   63.75
# 23       3828  Amazonas (ETC)           3232                   55.07
# 24       3828  Amazonas (ETC)            274                   83.94
# 25       3828  Amazonas (ETC)            211                    65.4
# 26       3828  Amazonas (ETC)            571                   49.39
# 27       3828  Amazonas (ETC)            169                    14.2
# 28       3828  Amazonas (ETC)           1203                   67.17
# 29       3828  Amazonas (ETC)           1197                   50.04
#
#    cobertura_neta  ... reprobaci_n_primaria reprobaci_n_secundaria  \
# 20          77.33  ...                13.35                   15.6
# 21          50.04  ...                 1.26                   24.2
# 22          63.75  ...                 3.09                   7.87
# 23          55.07  ...                13.51                  15.47
# 24          83.94  ...                 0.67                      0
# 25           65.4  ...                 9.38                   6.25
# 26          49.39  ...                    0                      0
# 27           14.2  ...                    0                      0
# 28          67.17  ...                  0.6                   5.73
# 29          50.04  ...                11.62                   8.64
#
#    reprobaci_n_media repitencia repitencia_transici_n repitencia_primaria  \
# 20              7.33      16.19                  8.47               18.36
# 21             63.16      26.09                  1.28               28.87
# 22                 0      16.67                  1.85               19.69
# 23              5.32      15.37                  5.85               18.61
# 24                 0      11.49                     0               12.75
# 25                 0      18.62                 29.41               19.79
# 26                 0       12.5                 17.65               11.05
# 27                 0      16.67                    20               15.79
# 28              4.62      12.97                  2.63               20.24
# 29                14      26.42                  5.56               24.77
#
#    repitencia_secundaria repitencia_media tama_o_promedio_de_grupo  \
# 20                 17.25             6.11                      NaN
# 21                  29.3            31.58                      NaN
# 22                 16.85            16.67                      NaN
# 23                 16.75             3.72                      NaN
# 24                 10.45            17.39                      NaN
# 25                  9.38                0                      NaN
# 26                    18             2.63                      NaN
# 27                     0                0                      NaN
# 28                  4.85             3.08                      NaN
# 29                 37.27               12                      NaN
#
#    sedes_conectadas_a_internet
# 20                         NaN
# 21                         NaN
# 22                         NaN
# 23                         NaN
# 24                         NaN
# 25                         NaN
# 26                         NaN
# 27                         NaN
# 28                         NaN
# 29                         NaN
#
# [10 rows x 41 columns]

# %%
df_raw.iloc[20:30] ## Acá si tuvo encuenta el 30, intervalo cerrado [20,30]
# Out:
#      a_o c_digo_municipio         municipio c_digo_departamento departamento  \
# 20  2023            94001           Inírida                  94      Guainía
# 21  2023            91798          Tarapacá                  91     Amazonas
# 22  2023            91669  Puerto Santander                  91     Amazonas
# 23  2023            91540     Puerto Nariño                  91     Amazonas
# 24  2023            91536      Puerto Arica                  91     Amazonas
# 25  2023            91530    Puerto Alegría                  91     Amazonas
# 26  2023            91460   Miriti - Paraná                  91     Amazonas
# 27  2023            91430       La Victoria                  91     Amazonas
# 28  2023            91407        La Pedrera                  91     Amazonas
# 29  2023            91405       La Chorrera                  91     Amazonas
#
#    c_digo_etc             etc poblaci_n_5_16 tasa_matriculaci_n_5_16  \
# 20       3829   Guainía (ETC)           9673                   77.42
# 21       3828  Amazonas (ETC)           1327                   50.04
# 22       3828  Amazonas (ETC)            618                   63.75
# 23       3828  Amazonas (ETC)           3232                   55.07
# 24       3828  Amazonas (ETC)            274                   83.94
# 25       3828  Amazonas (ETC)            211                    65.4
# 26       3828  Amazonas (ETC)            571                   49.39
# 27       3828  Amazonas (ETC)            169                    14.2
# 28       3828  Amazonas (ETC)           1203                   67.17
# 29       3828  Amazonas (ETC)           1197                   50.04
#
#    cobertura_neta  ... reprobaci_n_primaria reprobaci_n_secundaria  \
# 20          77.33  ...                13.35                   15.6
# 21          50.04  ...                 1.26                   24.2
# 22          63.75  ...                 3.09                   7.87
# 23          55.07  ...                13.51                  15.47
# 24          83.94  ...                 0.67                      0
# 25           65.4  ...                 9.38                   6.25
# 26          49.39  ...                    0                      0
# 27           14.2  ...                    0                      0
# 28          67.17  ...                  0.6                   5.73
# 29          50.04  ...                11.62                   8.64
#
#    reprobaci_n_media repitencia repitencia_transici_n repitencia_primaria  \
# 20              7.33      16.19                  8.47               18.36
# 21             63.16      26.09                  1.28               28.87
# 22                 0      16.67                  1.85               19.69
# 23              5.32      15.37                  5.85               18.61
# 24                 0      11.49                     0               12.75
# 25                 0      18.62                 29.41               19.79
# 26                 0       12.5                 17.65               11.05
# 27                 0      16.67                    20               15.79
# 28              4.62      12.97                  2.63               20.24
# 29                14      26.42                  5.56               24.77
#
#    repitencia_secundaria repitencia_media tama_o_promedio_de_grupo  \
# 20                 17.25             6.11                      NaN
# 21                  29.3            31.58                      NaN
# 22                 16.85            16.67                      NaN
# 23                 16.75             3.72                      NaN
# 24                 10.45            17.39                      NaN
# 25                  9.38                0                      NaN
# 26                    18             2.63                      NaN
# 27                     0                0                      NaN
# 28                  4.85             3.08                      NaN
# 29                 37.27               12                      NaN
#
#    sedes_conectadas_a_internet
# 20                         NaN
# 21                         NaN
# 22                         NaN
# 23                         NaN
# 24                         NaN
# 25                         NaN
# 26                         NaN
# 27                         NaN
# 28                         NaN
# 29                         NaN
#
# [10 rows x 41 columns]

# %% [markdown]
# 3. Muestra aleatoria

# %%
df_raw.sample(frac = 0.01, random_state=123456)
# Out:
#         a_o c_digo_municipio     municipio c_digo_departamento departamento  \
# 10516  2014            50330       Mesetas                  50         Meta
# 2152   2022             5628   Sabanalarga                   5    Antioquia
# 9454   2015            41660  Saladoblanco                  41        Huila
# 10130  2014            97889      Yavaraté                  97       Vaupés
# 11152  2014             5411      Liborina                   5    Antioquia
# ...     ...              ...           ...                 ...          ...
# 4912   2019            50251   El Castillo                  50         Meta
# 11711  2013            41503       Oporapa                  41        Huila
# 9773   2015            15897     Zetaquira                  15       Boyacá
# 3428   2020            81065     Arauquita                  81       Arauca
# 8460   2016            41006       Acevedo                  41        Huila
#
#       c_digo_etc              etc poblaci_n_5_16 tasa_matriculaci_n_5_16  \
# 10516       3796       Meta (ETC)           2904                   76.41
# 2152        3758  Antioquia (ETC)           2046                   79.33
# 9454        3790      Huila (ETC)           3108                   86.87
# 10130       3831     Vaupés (ETC)            386                   75.39
# 11152       3758  Antioquia (ETC)           1985                  105.29
# ...          ...              ...            ...                     ...
# 4912        3796       Meta (ETC)           1766                   95.13
# 11711       3790      Huila (ETC)           3997                   68.83
# 9773        3769     Boyacá (ETC)            981                   97.96
# 3428        3824     Arauca (ETC)          13580                   68.03
# 8460        3790      Huila (ETC)           9107                      81
#
#       cobertura_neta  ... reprobaci_n_primaria reprobaci_n_secundaria  \
# 10516          89.01  ...                    0                      0
# 2152           79.33  ...                 0.73                   0.87
# 9454           86.87  ...                 5.56                   0.47
# 10130          87.65  ...                    0                      0
# 11152          89.66  ...                    0                      0
# ...              ...  ...                  ...                    ...
# 4912           95.13  ...                 4.17                   3.89
# 11711           68.8  ...                 4.47                   9.14
# 9773           97.96  ...                    0                   4.52
# 3428           68.03  ...                 7.96                  15.51
# 8460           81.04  ...                 5.31                  11.24
#
#       reprobaci_n_media repitencia repitencia_transici_n repitencia_primaria  \
# 10516                 0          0                     0                   0
# 2152                  0       8.32                     0               12.39
# 9454               0.45       2.68                  1.95                3.96
# 10130                 0       3.61                     0                 4.9
# 11152                 0       2.87                  2.56                2.34
# ...                 ...        ...                   ...                 ...
# 4912                1.6       1.44                     0                1.19
# 11711              8.14       1.26                     0                2.09
# 9773               3.64       0.79                     0                1.48
# 3428               7.36       6.42                  1.93                5.15
# 8460               7.26       3.42                  0.69                4.48
#
#       repitencia_secundaria repitencia_media tama_o_promedio_de_grupo  \
# 10516                     0                0                    25.59
# 2152                   6.09             1.38                      NaN
# 9454                   1.29             0.45                    33.45
# 10130                  2.53                0                     9.76
# 11152                  3.62             3.52                    27.09
# ...                     ...              ...                      ...
# 4912                   2.54                0                      NaN
# 11711                  0.58                0                      NaN
# 9773                   0.53                0                    27.27
# 3428                  10.88             2.03                      NaN
# 8460                   2.44             2.35                   27.244
#
#       sedes_conectadas_a_internet
# 10516                        1.75
# 2152                          NaN
# 9454                         12.5
# 10130                       16.67
# 11152                       73.53
# ...                           ...
# 4912                          NaN
# 11711                       11.11
# 9773                            0
# 3428                          NaN
# 8460                        14.29
#
# [146 rows x 41 columns]

# %%
df_raw.sample(n = 10, random_state=123456)
# Out:
#         a_o c_digo_municipio     municipio c_digo_departamento departamento  \
# 10516  2014            50330       Mesetas                  50         Meta
# 2152   2022             5628   Sabanalarga                   5    Antioquia
# 9454   2015            41660  Saladoblanco                  41        Huila
# 10130  2014            97889      Yavaraté                  97       Vaupés
# 11152  2014             5411      Liborina                   5    Antioquia
# 2210   2022             5134    Campamento                   5    Antioquia
# 6968   2017            68368   Jesús María                  68    Santander
# 8852   2016            73675   San Antonio                  73       Tolima
# 13385  2012             5475       Murindó                   5    Antioquia
# 2067   2022            13458   Montecristo                  13      Bolívar
#
#       c_digo_etc              etc poblaci_n_5_16 tasa_matriculaci_n_5_16  \
# 10516       3796       Meta (ETC)           2904                   76.41
# 2152        3758  Antioquia (ETC)           2046                   79.33
# 9454        3790      Huila (ETC)           3108                   86.87
# 10130       3831     Vaupés (ETC)            386                   75.39
# 11152       3758  Antioquia (ETC)           1985                  105.29
# 2210        3758  Antioquia (ETC)           2223                   72.15
# 6968        3808  Santander (ETC)            657                    87.2
# 8852        3815     Tolima (ETC)           3510                    90.9
# 13385       3758  Antioquia (ETC)           1023                    95.6
# 2067        3767    Bolívar (ETC)           4308                   75.35
#
#       cobertura_neta  ... reprobaci_n_primaria reprobaci_n_secundaria  \
# 10516          89.01  ...                    0                      0
# 2152           79.33  ...                 0.73                   0.87
# 9454           86.87  ...                 5.56                   0.47
# 10130          87.65  ...                    0                      0
# 11152          89.66  ...                    0                      0
# 2210           72.15  ...                10.41                   6.99
# 6968           87.21  ...                 4.76                   9.42
# 8852           90.85  ...                 6.59                   8.57
# 13385           95.6  ...                    0                      0
# 2067           75.35  ...                10.87                  12.12
#
#       reprobaci_n_media repitencia repitencia_transici_n repitencia_primaria  \
# 10516                 0          0                     0                   0
# 2152                  0       8.32                     0               12.39
# 9454               0.45       2.68                  1.95                3.96
# 10130                 0       3.61                     0                 4.9
# 11152                 0       2.87                  2.56                2.34
# 2210               1.06       9.12                     0               13.49
# 6968               3.48          0                     0                   0
# 8852               5.08       0.18                     0                0.12
# 13385                 0          0                     0                   0
# 2067               1.79      13.41                  3.79               16.19
#
#       repitencia_secundaria repitencia_media tama_o_promedio_de_grupo  \
# 10516                     0                0                    25.59
# 2152                   6.09             1.38                      NaN
# 9454                   1.29             0.45                    33.45
# 10130                  2.53                0                     9.76
# 11152                  3.62             3.52                    27.09
# 2210                   6.99             0.53                      NaN
# 6968                      0                0                   25.333
# 8852                   0.18             0.68                   24.985
# 13385                     0                0                    30.33
# 2067                   13.2             3.57                      NaN
#
#       sedes_conectadas_a_internet
# 10516                        1.75
# 2152                          NaN
# 9454                         12.5
# 10130                       16.67
# 11152                       73.53
# 2210                          NaN
# 6968                         8.33
# 8852                        56.67
# 13385                           5
# 2067                          NaN
#
# [10 rows x 41 columns]

# %%
df_raw.tail(20) ## Ver la cola
# Out:
#         a_o c_digo_municipio             municipio c_digo_departamento  \
# 14565  2011             5107               Briceño                   5
# 14566  2011             5101        Ciudad Bolívar                   5
# 14567  2011             5093               Betulia                   5
# 14568  2011             5091               Betania                   5
# 14569  2011             5088                 Bello                   5
# 14570  2011             5086               Belmira                   5
# 14571  2011             5079               Barbosa                   5
# 14572  2011             5059               Armenia                   5
# 14573  2011             5055               Argelia                   5
# 14574  2011             5051             Arboletes                   5
# 14575  2011             5045              Apartadó                   5
# 14576  2011             5044                  Anza                   5
# 14577  2011             5042  Santafé de Antioquia                   5
# 14578  2011             5040                 Anorí                   5
# 14579  2011             5038             Angostura                   5
# 14580  2011             5036           Angelópolis                   5
# 14581  2011             5034                 Andes                   5
# 14582  2011             5031                Amalfi                   5
# 14583  2011             5030                 Amagá                   5
# 14584  2011             5021            Alejandría                   5
#
#       departamento c_digo_etc              etc poblaci_n_5_16  \
# 14565    Antioquia       3758  Antioquia (ETC)           2256
# 14566    Antioquia       3758  Antioquia (ETC)           6651
# 14567    Antioquia       3758  Antioquia (ETC)           4260
# 14568    Antioquia       3758  Antioquia (ETC)           2345
# 14569    Antioquia       3760            Bello          91582
# 14570    Antioquia       3758  Antioquia (ETC)           1700
# 14571    Antioquia       3758  Antioquia (ETC)          10933
# 14572    Antioquia       3758  Antioquia (ETC)           1097
# 14573    Antioquia       3758  Antioquia (ETC)           2460
# 14574    Antioquia       3758  Antioquia (ETC)          10673
# 14575    Antioquia       7692         Apartado          45592
# 14576    Antioquia       3758  Antioquia (ETC)           1873
# 14577    Antioquia       3758  Antioquia (ETC)           5963
# 14578    Antioquia       3758  Antioquia (ETC)           3983
# 14579    Antioquia       3758  Antioquia (ETC)           3344
# 14580    Antioquia       3758  Antioquia (ETC)           1707
# 14581    Antioquia       3758  Antioquia (ETC)          10244
# 14582    Antioquia       3758  Antioquia (ETC)           5552
# 14583    Antioquia       3758  Antioquia (ETC)           6631
# 14584    Antioquia       3758  Antioquia (ETC)            702
#
#       tasa_matriculaci_n_5_16 cobertura_neta  ... reprobaci_n_primaria  \
# 14565                    94.1           94.1  ...                  0.9
# 14566                   88.24           88.2  ...                 0.03
# 14567                   95.45           95.5  ...                11.11
# 14568                   89.85           89.9  ...                    0
# 14569                   82.53           82.4  ...                 0.12
# 14570                   97.76           97.8  ...                 1.92
# 14571                   82.05           82.1  ...                 7.55
# 14572                   87.97             88  ...                 7.11
# 14573                   88.58           88.6  ...                    0
# 14574                   84.85           84.9  ...                  3.1
# 14575                   66.51           66.5  ...                 0.47
# 14576                   86.07           86.1  ...                  NaN
# 14577                   84.59           84.6  ...                 6.14
# 14578                   92.09           92.1  ...                 2.14
# 14579                    81.7           81.7  ...                 3.73
# 14580                   78.85           78.9  ...                 3.61
# 14581                   84.45           84.5  ...                 0.58
# 14582                   97.71           97.7  ...                    0
# 14583                   78.65           78.7  ...                 6.73
# 14584                  118.52          118.5  ...                 2.16
#
#       reprobaci_n_secundaria reprobaci_n_media repitencia  \
# 14565                      0                 0       0.91
# 14566                      0              1.63       4.13
# 14567                  13.81              9.76       0.08
# 14568                      0                 0       0.48
# 14569                   0.11              1.35       3.12
# 14570                      0              0.58        NaN
# 14571                  12.47             13.01       1.02
# 14572                   2.65             14.74       4.21
# 14573                      0              0.53        NaN
# 14574                   3.74              4.91       2.25
# 14575                   1.98              2.07       1.86
# 14576                   5.69               3.7          0
# 14577                   5.47              4.13       3.25
# 14578                      1              0.42       0.48
# 14579                   1.93              2.27       3.92
# 14580                    9.5              7.32       0.71
# 14581                   0.04              2.69       5.41
# 14582                      0                 0        NaN
# 14583                  14.46              7.45       0.42
# 14584                   4.39              8.04        0.6
#
#       repitencia_transici_n repitencia_primaria repitencia_secundaria  \
# 14565                     0                1.28                  0.67
# 14566                     0                5.24                  3.54
# 14567                     0                0.12                     0
# 14568                     0                0.72                  0.17
# 14569                  0.41                2.39                  5.03
# 14570                  0.66                 NaN                   NaN
# 14571                     0                0.54                  2.07
# 14572                     0                 4.3                  6.18
# 14573                     0                 NaN                   2.3
# 14574                  0.66                2.41                  2.85
# 14575                  0.06                1.81                  2.67
# 14576                     0                   0                     0
# 14577                     0                2.36                  6.09
# 14578                     0                0.69                     0
# 14579                     0                5.16                  1.92
# 14580                     0                 0.7                  1.08
# 14581                  0.73                5.53                   6.9
# 14582                  0.83                 NaN                  9.93
# 14583                     0                0.24                  0.91
# 14584                     0                0.96                     0
#
#       repitencia_media tama_o_promedio_de_grupo sedes_conectadas_a_internet
# 14565                0                    16.28                       83.33
# 14566             2.77                    20.75                       97.06
# 14567                0                    26.89                        87.8
# 14568                0                    30.56                        96.3
# 14569             1.63                    28.52                        87.5
# 14570             5.85                    26.95                         100
# 14571             0.57                    29.49                          84
# 14572                0                    17.79                         100
# 14573             1.27                    31.07                       82.98
# 14574             0.73                    26.36                       47.22
# 14575             0.95                    26.21                       65.91
# 14576                0                     16.3                       88.89
# 14577             1.94                    23.04                       90.91
# 14578                0                    20.09                       63.93
# 14579             2.96                    20.29                       86.49
# 14580                0                    19.57                         100
# 14581             4.11                    24.43                       93.44
# 14582             4.47                    20.01                       53.45
# 14583                0                    25.05                       83.33
# 14584                0                    32.14                       81.25
#
# [20 rows x 41 columns]

# %% [markdown]
# Vamos a crear una copia del conjunto de datos, para cambiar los índices.

# %%
df_raw2 = df_raw.copy() ## importante para hacer cambios crear una copia

# %%
df_raw.shape ## atributo
# Out:
# (14585, 41)

# %%
df_raw2['new_index'] = range(1,df_raw.shape[0]+1) ### Cración de index

# %%
df_raw2.head(3)
# Out:
#     a_o c_digo_municipio   municipio c_digo_departamento departamento  \
# 0  2023            05004    Abriaquí                  05    Antioquia
# 1  2023            95025  El Retorno                  95     Guaviare
# 2  2023            95200  Miraflores                  95     Guaviare
#
#   c_digo_etc              etc poblaci_n_5_16 tasa_matriculaci_n_5_16  \
# 0       3758  Antioquia (ETC)            503                   62.62
# 1       3830   Guaviare (ETC)           4438                   53.27
# 2       3830   Guaviare (ETC)           2014                   32.52
#
#   cobertura_neta  ... reprobaci_n_secundaria reprobaci_n_media repitencia  \
# 0          62.62  ...                  16.51              2.04       9.52
# 1          53.27  ...                   9.39              1.75       9.34
# 2          32.52  ...                  14.13              7.81       8.65
#
#   repitencia_transici_n repitencia_primaria repitencia_secundaria  \
# 0                     0               10.46                 13.76
# 1                  6.95               11.84                  8.48
# 2                  6.67                9.04                 10.25
#
#   repitencia_media tama_o_promedio_de_grupo sedes_conectadas_a_internet  \
# 0             2.04                      NaN                         NaN
# 1             3.16                      NaN                         NaN
# 2             1.54                      NaN                         NaN
#
#   new_index
# 0         1
# 1         2
# 2         3
#
# [3 rows x 42 columns]

# %%
df_raw2.set_index('new_index', inplace = True)

# %%
df_raw2.head(2)
# Out:
#             a_o c_digo_municipio   municipio c_digo_departamento departamento  \
# new_index
# 1          2023            05004    Abriaquí                  05    Antioquia
# 2          2023            95025  El Retorno                  95     Guaviare
#
#           c_digo_etc              etc poblaci_n_5_16 tasa_matriculaci_n_5_16  \
# new_index
# 1               3758  Antioquia (ETC)            503                   62.62
# 2               3830   Guaviare (ETC)           4438                   53.27
#
#           cobertura_neta  ... reprobaci_n_primaria reprobaci_n_secundaria  \
# new_index                 ...
# 1                  62.62  ...                 1.96                  16.51
# 2                  53.27  ...                 7.11                   9.39
#
#           reprobaci_n_media repitencia repitencia_transici_n  \
# new_index
# 1                      2.04       9.52                     0
# 2                      1.75       9.34                  6.95
#
#           repitencia_primaria repitencia_secundaria repitencia_media  \
# new_index
# 1                       10.46                 13.76             2.04
# 2                       11.84                  8.48             3.16
#
#           tama_o_promedio_de_grupo sedes_conectadas_a_internet
# new_index
# 1                              NaN                         NaN
# 2                              NaN                         NaN
#
# [2 rows x 41 columns]

# %%
df_raw2.reset_index() ## quitarlo como index
# Out:
#        new_index   a_o c_digo_municipio    municipio c_digo_departamento  \
# 0              1  2023            05004     Abriaquí                  05
# 1              2  2023            95025   El Retorno                  95
# 2              3  2023            95200   Miraflores                  95
# 3              4  2023            97001         Mitú                  97
# 4              5  2023            97161       Caruru                  97
# ...          ...   ...              ...          ...                 ...
# 14580      14581  2011             5036  Angelópolis                   5
# 14581      14582  2011             5034        Andes                   5
# 14582      14583  2011             5031       Amalfi                   5
# 14583      14584  2011             5030        Amagá                   5
# 14584      14585  2011             5021   Alejandría                   5
#
#       departamento c_digo_etc              etc poblaci_n_5_16  \
# 0        Antioquia       3758  Antioquia (ETC)            503
# 1         Guaviare       3830   Guaviare (ETC)           4438
# 2         Guaviare       3830   Guaviare (ETC)           2014
# 3           Vaupés       3831     Vaupés (ETC)          10986
# 4           Vaupés       3831     Vaupés (ETC)           1228
# ...            ...        ...              ...            ...
# 14580    Antioquia       3758  Antioquia (ETC)           1707
# 14581    Antioquia       3758  Antioquia (ETC)          10244
# 14582    Antioquia       3758  Antioquia (ETC)           5552
# 14583    Antioquia       3758  Antioquia (ETC)           6631
# 14584    Antioquia       3758  Antioquia (ETC)            702
#
#       tasa_matriculaci_n_5_16  ... reprobaci_n_primaria  \
# 0                       62.62  ...                 1.96
# 1                       53.27  ...                 7.11
# 2                       32.52  ...                 6.93
# 3                       59.57  ...                 4.04
# 4                        51.3  ...                 7.32
# ...                       ...  ...                  ...
# 14580                   78.85  ...                 3.61
# 14581                   84.45  ...                 0.58
# 14582                   97.71  ...                    0
# 14583                   78.65  ...                 6.73
# 14584                  118.52  ...                 2.16
#
#       reprobaci_n_secundaria reprobaci_n_media repitencia  \
# 0                      16.51              2.04       9.52
# 1                       9.39              1.75       9.34
# 2                      14.13              7.81       8.65
# 3                       8.33               4.6      16.18
# 4                      15.28              7.27       9.24
# ...                      ...               ...        ...
# 14580                    9.5              7.32       0.71
# 14581                   0.04              2.69       5.41
# 14582                      0                 0        NaN
# 14583                  14.46              7.45       0.42
# 14584                   4.39              8.04        0.6
#
#       repitencia_transici_n repitencia_primaria repitencia_secundaria  \
# 0                         0               10.46                 13.76
# 1                      6.95               11.84                  8.48
# 2                      6.67                9.04                 10.25
# 3                      7.75               21.04                 13.84
# 4                      2.86                7.62                 14.85
# ...                     ...                 ...                   ...
# 14580                     0                 0.7                  1.08
# 14581                  0.73                5.53                   6.9
# 14582                  0.83                 NaN                  9.93
# 14583                     0                0.24                  0.91
# 14584                     0                0.96                     0
#
#       repitencia_media tama_o_promedio_de_grupo sedes_conectadas_a_internet
# 0                 2.04                      NaN                         NaN
# 1                 3.16                      NaN                         NaN
# 2                 1.54                      NaN                         NaN
# 3                 7.18                      NaN                         NaN
# 4                 3.64                      NaN                         NaN
# ...                ...                      ...                         ...
# 14580                0                    19.57                         100
# 14581             4.11                    24.43                       93.44
# 14582             4.47                    20.01                       53.45
# 14583                0                    25.05                       83.33
# 14584                0                    32.14                       81.25
#
# [14585 rows x 42 columns]

# %% [markdown]
# Para evaluar si existen registros repetidos, usamos el método `drop_duplicate`

# %%
df_raw.drop_duplicates().shape
# Out:
# (14585, 41)

# %% [markdown]
# ## Coversión de Variables Según su Naturaleza

# %%
## si no la hay creela y si la hay transformela

df_raw['tasa_matriculaci_n_5_16'] = df_raw['tasa_matriculaci_n_5_16'].astype(float)

# %%
df_raw['tasa_matriculaci_n_5_16'].describe()
# Out:
# count    14470.000000
# mean        84.971929
# std         18.589112
# min          0.000000
# 25%         74.850000
# 50%         85.330000
# 75%         95.380000
# max        279.030000
# Name: tasa_matriculaci_n_5_16, dtype: float64

# %% [markdown]
# Ahora, vamos a generar una estadística de resumen a nivel de departamentos

# %%
df_raw.groupby(['c_digo_departamento', 'departamento']) ['tasa_matriculaci_n_5_16'].mean().reset_index() ## aclarar dentro de una lista cuales son las variables agrupadoras
# Out:
#    c_digo_departamento                                       departamento  \
# 0                    0                                           NACIONAL
# 1                   05                                          Antioquia
# 2                   08                                          Atlántico
# 3                   11                                        Bogotá D.C.
# 4                   11                                       Bogotá, D.C.
# 5                   13                                            Bolívar
# 6                   15                                             Boyacá
# 7                   17                                             Caldas
# 8                   18                                            Caquetá
# 9                   19                                              Cauca
# 10                  20                                              Cesar
# 11                  23                                            Córdoba
# 12                  25                                       Cundinamarca
# 13                  27                                              Chocó
# 14                  41                                              Huila
# 15                  44                                         La Guajira
# 16                  47                                          Magdalena
# 17                   5                                          Antioquia
# 18                  50                                               Meta
# 19                  52                                             Nariño
# 20                  54                                 Norte de Santander
# 21                  63                                            Quindio
# 22                  66                                          Risaralda
# 23                  68                                          Santander
# 24                  70                                              Sucre
# 25                  73                                             Tolima
# 26                  76                                    Valle del Cauca
# 27                   8                                          Atlántico
# 28                  81                                             Arauca
# 29                  85                                           Casanare
# 30                  86                                           Putumayo
# 31                  88  Archipiélago de San Andrés, Providencia y Sant...
# 32                  88  Archipiélago de San Andrés. Providencia y Sant...
# 33                  91                                           Amazonas
# 34                  94                                            Guainía
# 35                  95                                           Guaviare
# 36                  97                                             Vaupés
# 37                  99                                            Vichada
#
#     tasa_matriculaci_n_5_16
# 0                  0.922600
# 1                 84.215040
# 2                 83.640435
# 3                 96.410000
# 4                 86.860833
# 5                 86.463798
# 6                 82.983827
# 7                 82.187436
# 8                 75.105529
# 9                 79.346987
# 10                96.113944
# 11                88.003057
# 12                87.205280
# 13                80.573439
# 14                85.088420
# 15                80.790923
# 16                94.591410
# 17                88.194655
# 18                91.258147
# 19                75.909501
# 20                83.849499
# 21                93.880000
# 22                84.438242
# 23                87.187691
# 24                95.251538
# 25                87.923552
# 26                84.256264
# 27                89.949373
# 28                79.976484
# 29                89.254321
# 30                79.806647
# 31                80.197083
# 32                84.980000
# 33                57.911240
# 34                60.224216
# 35                56.902692
# 36                60.409855
# 37                79.675769

# %% [markdown]
# Como `NACIONAL` no es depto, se quita

# %%
df_raw[df_raw['departamento'] != 'NACIONAL']
# Out:
#         a_o c_digo_municipio    municipio c_digo_departamento departamento  \
# 0      2023            05004     Abriaquí                  05    Antioquia
# 1      2023            95025   El Retorno                  95     Guaviare
# 2      2023            95200   Miraflores                  95     Guaviare
# 3      2023            97001         Mitú                  97       Vaupés
# 4      2023            97161       Caruru                  97       Vaupés
# ...     ...              ...          ...                 ...          ...
# 14580  2011             5036  Angelópolis                   5    Antioquia
# 14581  2011             5034        Andes                   5    Antioquia
# 14582  2011             5031       Amalfi                   5    Antioquia
# 14583  2011             5030        Amagá                   5    Antioquia
# 14584  2011             5021   Alejandría                   5    Antioquia
#
#       c_digo_etc              etc poblaci_n_5_16  tasa_matriculaci_n_5_16  \
# 0           3758  Antioquia (ETC)            503                    62.62
# 1           3830   Guaviare (ETC)           4438                    53.27
# 2           3830   Guaviare (ETC)           2014                    32.52
# 3           3831     Vaupés (ETC)          10986                    59.57
# 4           3831     Vaupés (ETC)           1228                    51.30
# ...          ...              ...            ...                      ...
# 14580       3758  Antioquia (ETC)           1707                    78.85
# 14581       3758  Antioquia (ETC)          10244                    84.45
# 14582       3758  Antioquia (ETC)           5552                    97.71
# 14583       3758  Antioquia (ETC)           6631                    78.65
# 14584       3758  Antioquia (ETC)            702                   118.52
#
#       cobertura_neta  ... reprobaci_n_primaria reprobaci_n_secundaria  \
# 0              62.62  ...                 1.96                  16.51
# 1              53.27  ...                 7.11                   9.39
# 2              32.52  ...                 6.93                  14.13
# 3              59.57  ...                 4.04                   8.33
# 4               51.3  ...                 7.32                  15.28
# ...              ...  ...                  ...                    ...
# 14580           78.9  ...                 3.61                    9.5
# 14581           84.5  ...                 0.58                   0.04
# 14582           97.7  ...                    0                      0
# 14583           78.7  ...                 6.73                  14.46
# 14584          118.5  ...                 2.16                   4.39
#
#       reprobaci_n_media repitencia repitencia_transici_n repitencia_primaria  \
# 0                  2.04       9.52                     0               10.46
# 1                  1.75       9.34                  6.95               11.84
# 2                  7.81       8.65                  6.67                9.04
# 3                   4.6      16.18                  7.75               21.04
# 4                  7.27       9.24                  2.86                7.62
# ...                 ...        ...                   ...                 ...
# 14580              7.32       0.71                     0                 0.7
# 14581              2.69       5.41                  0.73                5.53
# 14582                 0        NaN                  0.83                 NaN
# 14583              7.45       0.42                     0                0.24
# 14584              8.04        0.6                     0                0.96
#
#       repitencia_secundaria repitencia_media tama_o_promedio_de_grupo  \
# 0                     13.76             2.04                      NaN
# 1                      8.48             3.16                      NaN
# 2                     10.25             1.54                      NaN
# 3                     13.84             7.18                      NaN
# 4                     14.85             3.64                      NaN
# ...                     ...              ...                      ...
# 14580                  1.08                0                    19.57
# 14581                   6.9             4.11                    24.43
# 14582                  9.93             4.47                    20.01
# 14583                  0.91                0                    25.05
# 14584                     0                0                    32.14
#
#       sedes_conectadas_a_internet
# 0                             NaN
# 1                             NaN
# 2                             NaN
# 3                             NaN
# 4                             NaN
# ...                           ...
# 14580                         100
# 14581                       93.44
# 14582                       53.45
# 14583                       83.33
# 14584                       81.25
#
# [14582 rows x 41 columns]

# %%
df_raw.query("departamento != 'NACIONAL'")
# Out:
#         a_o c_digo_municipio    municipio c_digo_departamento departamento  \
# 0      2023            05004     Abriaquí                  05    Antioquia
# 1      2023            95025   El Retorno                  95     Guaviare
# 2      2023            95200   Miraflores                  95     Guaviare
# 3      2023            97001         Mitú                  97       Vaupés
# 4      2023            97161       Caruru                  97       Vaupés
# ...     ...              ...          ...                 ...          ...
# 14580  2011             5036  Angelópolis                   5    Antioquia
# 14581  2011             5034        Andes                   5    Antioquia
# 14582  2011             5031       Amalfi                   5    Antioquia
# 14583  2011             5030        Amagá                   5    Antioquia
# 14584  2011             5021   Alejandría                   5    Antioquia
#
#       c_digo_etc              etc poblaci_n_5_16  tasa_matriculaci_n_5_16  \
# 0           3758  Antioquia (ETC)            503                    62.62
# 1           3830   Guaviare (ETC)           4438                    53.27
# 2           3830   Guaviare (ETC)           2014                    32.52
# 3           3831     Vaupés (ETC)          10986                    59.57
# 4           3831     Vaupés (ETC)           1228                    51.30
# ...          ...              ...            ...                      ...
# 14580       3758  Antioquia (ETC)           1707                    78.85
# 14581       3758  Antioquia (ETC)          10244                    84.45
# 14582       3758  Antioquia (ETC)           5552                    97.71
# 14583       3758  Antioquia (ETC)           6631                    78.65
# 14584       3758  Antioquia (ETC)            702                   118.52
#
#       cobertura_neta  ... reprobaci_n_primaria reprobaci_n_secundaria  \
# 0              62.62  ...                 1.96                  16.51
# 1              53.27  ...                 7.11                   9.39
# 2              32.52  ...                 6.93                  14.13
# 3              59.57  ...                 4.04                   8.33
# 4               51.3  ...                 7.32                  15.28
# ...              ...  ...                  ...                    ...
# 14580           78.9  ...                 3.61                    9.5
# 14581           84.5  ...                 0.58                   0.04
# 14582           97.7  ...                    0                      0
# 14583           78.7  ...                 6.73                  14.46
# 14584          118.5  ...                 2.16                   4.39
#
#       reprobaci_n_media repitencia repitencia_transici_n repitencia_primaria  \
# 0                  2.04       9.52                     0               10.46
# 1                  1.75       9.34                  6.95               11.84
# 2                  7.81       8.65                  6.67                9.04
# 3                   4.6      16.18                  7.75               21.04
# 4                  7.27       9.24                  2.86                7.62
# ...                 ...        ...                   ...                 ...
# 14580              7.32       0.71                     0                 0.7
# 14581              2.69       5.41                  0.73                5.53
# 14582                 0        NaN                  0.83                 NaN
# 14583              7.45       0.42                     0                0.24
# 14584              8.04        0.6                     0                0.96
#
#       repitencia_secundaria repitencia_media tama_o_promedio_de_grupo  \
# 0                     13.76             2.04                      NaN
# 1                      8.48             3.16                      NaN
# 2                     10.25             1.54                      NaN
# 3                     13.84             7.18                      NaN
# 4                     14.85             3.64                      NaN
# ...                     ...              ...                      ...
# 14580                  1.08                0                    19.57
# 14581                   6.9             4.11                    24.43
# 14582                  9.93             4.47                    20.01
# 14583                  0.91                0                    25.05
# 14584                     0                0                    32.14
#
#       sedes_conectadas_a_internet
# 0                             NaN
# 1                             NaN
# 2                             NaN
# 3                             NaN
# 4                             NaN
# ...                           ...
# 14580                         100
# 14581                       93.44
# 14582                       53.45
# 14583                       83.33
# 14584                       81.25
#
# [14582 rows x 41 columns]

# %%
resumen_matriculados_v0=(
    df_raw
    .query("departamento != 'NACIONAL' ")
    .groupby(['c_digo_departamento','departamento'])
    ['tasa_matriculaci_n_5_16']
    .mean()
    .reset_index()
)

# %%
resumen_matriculados_v0
# Out:
#    c_digo_departamento                                       departamento  \
# 0                   05                                          Antioquia
# 1                   08                                          Atlántico
# 2                   11                                        Bogotá D.C.
# 3                   11                                       Bogotá, D.C.
# 4                   13                                            Bolívar
# 5                   15                                             Boyacá
# 6                   17                                             Caldas
# 7                   18                                            Caquetá
# 8                   19                                              Cauca
# 9                   20                                              Cesar
# 10                  23                                            Córdoba
# 11                  25                                       Cundinamarca
# 12                  27                                              Chocó
# 13                  41                                              Huila
# 14                  44                                         La Guajira
# 15                  47                                          Magdalena
# 16                   5                                          Antioquia
# 17                  50                                               Meta
# 18                  52                                             Nariño
# 19                  54                                 Norte de Santander
# 20                  63                                            Quindio
# 21                  66                                          Risaralda
# 22                  68                                          Santander
# 23                  70                                              Sucre
# 24                  73                                             Tolima
# 25                  76                                    Valle del Cauca
# 26                   8                                          Atlántico
# 27                  81                                             Arauca
# 28                  85                                           Casanare
# 29                  86                                           Putumayo
# 30                  88  Archipiélago de San Andrés, Providencia y Sant...
# 31                  88  Archipiélago de San Andrés. Providencia y Sant...
# 32                  91                                           Amazonas
# 33                  94                                            Guainía
# 34                  95                                           Guaviare
# 35                  97                                             Vaupés
# 36                  99                                            Vichada
#
#     tasa_matriculaci_n_5_16
# 0                 84.215040
# 1                 83.640435
# 2                 96.410000
# 3                 86.860833
# 4                 86.463798
# 5                 82.983827
# 6                 82.187436
# 7                 75.105529
# 8                 79.346987
# 9                 96.113944
# 10                88.003057
# 11                87.205280
# 12                80.573439
# 13                85.088420
# 14                80.790923
# 15                94.591410
# 16                88.194655
# 17                91.258147
# 18                75.909501
# 19                83.849499
# 20                93.880000
# 21                84.438242
# 22                87.187691
# 23                95.251538
# 24                87.923552
# 25                84.256264
# 26                89.949373
# 27                79.976484
# 28                89.254321
# 29                79.806647
# 30                80.197083
# 31                84.980000
# 32                57.911240
# 33                60.224216
# 34                56.902692
# 35                60.409855
# 36                79.675769

# %%
def ajuste_cod_depto(codigo):
    if len(codigo)==1:
        codigo = '0' + codigo
    return codigo

# %%
ajuste_cod_depto('8') ## le pone 08
# Out:
# '08'

# %% [markdown]
# Vamos a aplicar esta función a todo el conjunto de datos

# %%
df_raw['c_digo_departamento'] = df_raw['c_digo_departamento'].apply(ajuste_cod_depto)

# %%
tabla_deptos = (
    df_raw
    .query("departamento != 'NACIONAL'")
    [['c_digo_departamento', 'departamento']]
    .drop_duplicates()
    .groupby('c_digo_departamento')
    .sample(n=1, random_state=1)
    .reset_index()
)

# %%
tabla_deptos
# Out:
#     index c_digo_departamento  \
# 0       0                  05
# 1     975                  08
# 2     974                  11
# 3     928                  13
# 4     805                  15
# 5     778                  17
# 6     762                  18
# 7     720                  19
# 8     695                  20
# 9     665                  23
# 10    548                  25
# 11    517                  27
# 12    480                  41
# 13    465                  44
# 14    435                  47
# 15    406                  50
# 16    342                  52
# 17    302                  54
# 18    290                  63
# 19    276                  66
# 20    189                  68
# 21    163                  70
# 22    115                  73
# 23     73                  76
# 24     66                  81
# 25     47                  85
# 26     34                  86
# 27     32                  88
# 28     21                  91
# 29     14                  94
# 30      1                  95
# 31      3                  97
# 32      9                  99
#
#                                          departamento
# 0                                           Antioquia
# 1                                           Atlántico
# 2                                        Bogotá, D.C.
# 3                                             Bolívar
# 4                                              Boyacá
# 5                                              Caldas
# 6                                             Caquetá
# 7                                               Cauca
# 8                                               Cesar
# 9                                             Córdoba
# 10                                       Cundinamarca
# 11                                              Chocó
# 12                                              Huila
# 13                                         La Guajira
# 14                                          Magdalena
# 15                                               Meta
# 16                                             Nariño
# 17                                 Norte de Santander
# 18                                            Quindio
# 19                                          Risaralda
# 20                                          Santander
# 21                                              Sucre
# 22                                             Tolima
# 23                                    Valle del Cauca
# 24                                             Arauca
# 25                                           Casanare
# 26                                           Putumayo
# 27  Archipiélago de San Andrés, Providencia y Sant...
# 28                                           Amazonas
# 29                                            Guainía
# 30                                           Guaviare
# 31                                             Vaupés
# 32                                            Vichada

# %%
df_raw = (
    df_raw
    .query("departamento != 'NACIONAL'")
    .drop(columns='departamento')
    .merge(tabla_deptos, on='c_digo_departamento', how='left')
)
df_raw.head(4)
# Out:
#     a_o c_digo_municipio   municipio c_digo_departamento c_digo_etc  \
# 0  2023            05004    Abriaquí                  05       3758
# 1  2023            95025  El Retorno                  95       3830
# 2  2023            95200  Miraflores                  95       3830
# 3  2023            97001        Mitú                  97       3831
#
#                etc poblaci_n_5_16  tasa_matriculaci_n_5_16 cobertura_neta  \
# 0  Antioquia (ETC)            503                    62.62          62.62
# 1   Guaviare (ETC)           4438                    53.27          53.27
# 2   Guaviare (ETC)           2014                    32.52          32.52
# 3     Vaupés (ETC)          10986                    59.57          59.57
#
#   cobertura_neta_transici_n  ... reprobaci_n_media repitencia  \
# 0                     44.19  ...              2.04       9.52
# 1                     33.91  ...              1.75       9.34
# 2                     17.58  ...              7.81       8.65
# 3                     42.76  ...               4.6      16.18
#
#   repitencia_transici_n repitencia_primaria repitencia_secundaria  \
# 0                     0               10.46                 13.76
# 1                  6.95               11.84                  8.48
# 2                  6.67                9.04                 10.25
# 3                  7.75               21.04                 13.84
#
#   repitencia_media tama_o_promedio_de_grupo sedes_conectadas_a_internet index  \
# 0             2.04                      NaN                         NaN     0
# 1             3.16                      NaN                         NaN     1
# 2             1.54                      NaN                         NaN     1
# 3             7.18                      NaN                         NaN     3
#
#   departamento
# 0    Antioquia
# 1     Guaviare
# 2     Guaviare
# 3       Vaupés
#
# [4 rows x 42 columns]

# %%
resumen_matriculados_v0=(
    df_raw
    .query("departamento != 'NACIONAL' ")
    .groupby(['c_digo_departamento','departamento'])
    ['tasa_matriculaci_n_5_16']
    .mean()
    .reset_index()
)
resumen_matriculados_v0
# Out:
#    c_digo_departamento                                       departamento  \
# 0                   05                                          Antioquia
# 1                   08                                          Atlántico
# 2                   11                                       Bogotá, D.C.
# 3                   13                                            Bolívar
# 4                   15                                             Boyacá
# 5                   17                                             Caldas
# 6                   18                                            Caquetá
# 7                   19                                              Cauca
# 8                   20                                              Cesar
# 9                   23                                            Córdoba
# 10                  25                                       Cundinamarca
# 11                  27                                              Chocó
# 12                  41                                              Huila
# 13                  44                                         La Guajira
# 14                  47                                          Magdalena
# 15                  50                                               Meta
# 16                  52                                             Nariño
# 17                  54                                 Norte de Santander
# 18                  63                                            Quindio
# 19                  66                                          Risaralda
# 20                  68                                          Santander
# 21                  70                                              Sucre
# 22                  73                                             Tolima
# 23                  76                                    Valle del Cauca
# 24                  81                                             Arauca
# 25                  85                                           Casanare
# 26                  86                                           Putumayo
# 27                  88  Archipiélago de San Andrés, Providencia y Sant...
# 28                  91                                           Amazonas
# 29                  94                                            Guainía
# 30                  95                                           Guaviare
# 31                  97                                             Vaupés
# 32                  99                                            Vichada
#
#     tasa_matriculaci_n_5_16
# 0                 87.887206
# 1                 89.455816
# 2                 87.595385
# 3                 86.463798
# 4                 82.983827
# 5                 82.187436
# 6                 75.105529
# 7                 79.346987
# 8                 96.113944
# 9                 88.003057
# 10                87.205280
# 11                80.573439
# 12                85.088420
# 13                80.790923
# 14                94.591410
# 15                91.258147
# 16                75.909501
# 17                83.849499
# 18                93.880000
# 19                84.438242
# 20                87.187691
# 21                95.251538
# 22                87.923552
# 23                84.256264
# 24                79.976484
# 25                89.254321
# 26                79.806647
# 27                80.565000
# 28                57.911240
# 29                60.224216
# 30                56.902692
# 31                60.409855
# 32                79.675769

# %%
def longitud_cod_mpio(codigo):
    return len(codigo)


set(
    df_raw
    .query("departamento != 'NACIONAL' ")
    .assign(len_codigo_mpio = lambda x: x['c_digo_municipio'].apply(longitud_cod_mpio)) 
    ['len_codigo_mpio']
    .astype(str)
)
# Out:
# {'4', '5'}

# %%
def ajuste_cod_mpio(codigo):
    if len(codigo)==4:
        codigo = '0' + codigo
    return codigo

# %%
df_raw['c_digo_municipio'] = df_raw['c_digo_municipio'].apply(ajuste_cod_mpio)

# %%
pd.set_option('display.max_columns', None) ## muestra todos los datos
df_raw
# Out:
#         a_o c_digo_municipio    municipio c_digo_departamento c_digo_etc  \
# 0      2023            05004     Abriaquí                  05       3758
# 1      2023            95025   El Retorno                  95       3830
# 2      2023            95200   Miraflores                  95       3830
# 3      2023            97001         Mitú                  97       3831
# 4      2023            97161       Caruru                  97       3831
# ...     ...              ...          ...                 ...        ...
# 14577  2011            05036  Angelópolis                  05       3758
# 14578  2011            05034        Andes                  05       3758
# 14579  2011            05031       Amalfi                  05       3758
# 14580  2011            05030        Amagá                  05       3758
# 14581  2011            05021   Alejandría                  05       3758
#
#                    etc poblaci_n_5_16  tasa_matriculaci_n_5_16 cobertura_neta  \
# 0      Antioquia (ETC)            503                    62.62          62.62
# 1       Guaviare (ETC)           4438                    53.27          53.27
# 2       Guaviare (ETC)           2014                    32.52          32.52
# 3         Vaupés (ETC)          10986                    59.57          59.57
# 4         Vaupés (ETC)           1228                    51.30           51.3
# ...                ...            ...                      ...            ...
# 14577  Antioquia (ETC)           1707                    78.85           78.9
# 14578  Antioquia (ETC)          10244                    84.45           84.5
# 14579  Antioquia (ETC)           5552                    97.71           97.7
# 14580  Antioquia (ETC)           6631                    78.65           78.7
# 14581  Antioquia (ETC)            702                   118.52          118.5
#
#       cobertura_neta_transici_n cobertura_neta_primaria  \
# 0                         44.19                   63.33
# 1                         33.91                   48.89
# 2                         17.58                   25.33
# 3                         42.76                   55.95
# 4                         76.32                   52.29
# ...                         ...                     ...
# 14577                      56.2                    82.4
# 14578                      65.1                    83.7
# 14579                      61.7                   107.2
# 14580                      55.3                    76.3
# 14581                      82.7                   127.6
#
#       cobertura_neta_secundaria cobertura_neta_media cobertura_bruta  \
# 0                         51.53                40.23            66.8
# 1                          44.9                 21.3           62.98
# 2                         26.43                10.75           38.58
# 3                         43.51                17.06           70.65
# 4                         33.71                11.94           55.54
# ...                         ...                  ...             ...
# 14577                      59.9                 26.4            82.8
# 14578                        62                 32.2            91.7
# 14579                      65.1                 27.3           108.4
# 14580                      70.7                 38.9            87.7
# 14581                      90.2                 48.5           134.9
#
#       cobertura_bruta_transici_n cobertura_bruta_primaria  \
# 0                          58.14                    72.86
# 1                           54.2                    65.19
# 2                          36.36                    37.28
# 3                           64.9                    76.96
# 4                          92.11                    65.21
# ...                          ...                      ...
# 14577                       77.4                      105
# 14578                       81.1                    107.5
# 14579                       77.9                    146.8
# 14580                       74.3                     89.8
# 14581                       86.5                    159.8
#
#       cobertura_bruta_secundaria cobertura_bruta_media deserci_n  \
# 0                          66.87                 56.32      1.19
# 1                           69.6                 48.54      5.56
# 2                           46.1                 26.16      7.85
# 3                          72.92                 53.12      3.95
# 4                          51.12                 27.36      8.36
# ...                          ...                   ...       ...
# 14577                       80.4                  40.1      8.14
# 14578                       89.9                  61.4      3.96
# 14579                       97.3                  53.9      8.75
# 14580                       96.3                  73.2      4.16
# 14581                      140.8                    94      4.03
#
#       deserci_n_transici_n deserci_n_primaria deserci_n_secundaria  \
# 0                        0               1.31                    0
# 1                     6.95               4.99                 6.11
# 2                       15               8.43                 6.36
# 3                     2.27               1.84                 6.77
# 4                     4.29               3.05                15.72
# ...                    ...                ...                  ...
# 14577                  6.6                6.1                13.17
# 14578                 3.06                4.3                 4.36
# 14579                 5.83               8.59                 9.49
# 14580                 2.39               3.23                 6.12
# 14581                  NaN                NaN                 8.46
#
#       deserci_n_media aprobaci_n aprobaci_n_transici_n aprobaci_n_primaria  \
# 0                4.08      92.26                     0               96.73
# 1                5.26      87.67                     0                87.9
# 2                4.69      82.68                  3.33               84.64
# 3                5.47      90.71                  0.57               94.12
# 4               14.55       82.4                     0               89.63
# ...               ...        ...                   ...                 ...
# 14577            2.44      86.27                     0               90.29
# 14578            1.68      95.46                     0               95.12
# 14579            9.74      91.25                     0               91.41
# 14580            3.21      86.86                  0.24               90.04
# 14581            8.04      92.39                     0               97.84
#
#       aprobaci_n_secundaria aprobaci_n_media reprobaci_n  \
# 0                     83.49            93.88        6.55
# 1                      84.5            92.98        6.78
# 2                     79.51             87.5        9.47
# 3                     84.91            89.93        5.34
# 4                        69            78.18        9.24
# ...                     ...              ...         ...
# 14577                 77.32            90.24        5.59
# 14578                 95.61            95.63        0.58
# 14579                 90.51            90.26           0
# 14580                 79.42            89.34        8.99
# 14581                 87.15            83.93        3.58
#
#       reprobaci_n_transici_n reprobaci_n_primaria reprobaci_n_secundaria  \
# 0                          0                 1.96                  16.51
# 1                          0                 7.11                   9.39
# 2                       3.33                 6.93                  14.13
# 3                       0.57                 4.04                   8.33
# 4                          0                 7.32                  15.28
# ...                      ...                  ...                    ...
# 14577                      0                 3.61                    9.5
# 14578                      0                 0.58                   0.04
# 14579                      0                    0                      0
# 14580                   0.24                 6.73                  14.46
# 14581                      0                 2.16                   4.39
#
#       reprobaci_n_media repitencia repitencia_transici_n repitencia_primaria  \
# 0                  2.04       9.52                     0               10.46
# 1                  1.75       9.34                  6.95               11.84
# 2                  7.81       8.65                  6.67                9.04
# 3                   4.6      16.18                  7.75               21.04
# 4                  7.27       9.24                  2.86                7.62
# ...                 ...        ...                   ...                 ...
# 14577              7.32       0.71                     0                 0.7
# 14578              2.69       5.41                  0.73                5.53
# 14579                 0        NaN                  0.83                 NaN
# 14580              7.45       0.42                     0                0.24
# 14581              8.04        0.6                     0                0.96
#
#       repitencia_secundaria repitencia_media tama_o_promedio_de_grupo  \
# 0                     13.76             2.04                      NaN
# 1                      8.48             3.16                      NaN
# 2                     10.25             1.54                      NaN
# 3                     13.84             7.18                      NaN
# 4                     14.85             3.64                      NaN
# ...                     ...              ...                      ...
# 14577                  1.08                0                    19.57
# 14578                   6.9             4.11                    24.43
# 14579                  9.93             4.47                    20.01
# 14580                  0.91                0                    25.05
# 14581                     0                0                    32.14
#
#       sedes_conectadas_a_internet  index departamento
# 0                             NaN      0    Antioquia
# 1                             NaN      1     Guaviare
# 2                             NaN      1     Guaviare
# 3                             NaN      3       Vaupés
# 4                             NaN      3       Vaupés
# ...                           ...    ...          ...
# 14577                         100      0    Antioquia
# 14578                       93.44      0    Antioquia
# 14579                       53.45      0    Antioquia
# 14580                       83.33      0    Antioquia
# 14581                       81.25      0    Antioquia
#
# [14582 rows x 42 columns]

# %%
#df_raw = df_raw.drop(columns=['index']) ## Index no nos sirve, lo podemos eliminar

# %%
df_raw = df_raw.drop(columns=['c_digo_etc', 'etc'])

# %%
df_raw.dtypes
# Out:
# a_o                             object
# c_digo_municipio                object
# municipio                       object
# c_digo_departamento             object
# poblaci_n_5_16                  object
# tasa_matriculaci_n_5_16        float64
# cobertura_neta                  object
# cobertura_neta_transici_n       object
# cobertura_neta_primaria         object
# cobertura_neta_secundaria       object
# cobertura_neta_media            object
# cobertura_bruta                 object
# cobertura_bruta_transici_n      object
# cobertura_bruta_primaria        object
# cobertura_bruta_secundaria      object
# cobertura_bruta_media           object
# deserci_n                       object
# deserci_n_transici_n            object
# deserci_n_primaria              object
# deserci_n_secundaria            object
# deserci_n_media                 object
# aprobaci_n                      object
# aprobaci_n_transici_n           object
# aprobaci_n_primaria             object
# aprobaci_n_secundaria           object
# aprobaci_n_media                object
# reprobaci_n                     object
# reprobaci_n_transici_n          object
# reprobaci_n_primaria            object
# reprobaci_n_secundaria          object
# reprobaci_n_media               object
# repitencia                      object
# repitencia_transici_n           object
# repitencia_primaria             object
# repitencia_secundaria           object
# repitencia_media                object
# tama_o_promedio_de_grupo        object
# sedes_conectadas_a_internet     object
# index                            int64
# departamento                    object
# dtype: object

# %%
### arreglar formatos de texto

columnas_numericas = [
    'poblaci_n_5_16',
    'cobertura_neta', 'cobertura_neta_transici_n', 'cobertura_neta_primaria',
    'cobertura_neta_secundaria', 'cobertura_neta_media',
    'cobertura_bruta', 'cobertura_bruta_transici_n', 'cobertura_bruta_primaria',
    'cobertura_bruta_secundaria', 'cobertura_bruta_media',
    'deserci_n', 'deserci_n_transici_n', 'deserci_n_primaria', 'deserci_n_secundaria',
    'deserci_n_media', 'aprobaci_n', 'aprobaci_n_transici_n', 'aprobaci_n_primaria',
    'aprobaci_n_secundaria', 'aprobaci_n_media', 'reprobaci_n', 'reprobaci_n_transici_n',
    'reprobaci_n_primaria', 'reprobaci_n_secundaria', 'reprobaci_n_media',
    'repitencia', 'repitencia_transici_n', 'repitencia_primaria',
    'repitencia_secundaria', 'repitencia_media', 'tama_o_promedio_de_grupo',
    'sedes_conectadas_a_internet'
]

for col in columnas_numericas:
    df_raw[col] = (
        df_raw[col]
        .astype(str)
        .str.replace(',', '', regex=False)  # quitar separadores de miles
        .str.replace('%', '', regex=False)  # quitar simbolos de porcentaje si hay
        .replace('', None)                  # reemplazar vacíos por NaN
        .astype(float)
    )

# %%
## formato texto correcto

df_raw['c_digo_municipio'] = df_raw['c_digo_municipio'].astype(str).str.zfill(5)
df_raw['c_digo_departamento'] = df_raw['c_digo_departamento'].astype(str).str.zfill(2)

# %%
df_raw.dtypes
# Out:
# a_o                             object
# c_digo_municipio                object
# municipio                       object
# c_digo_departamento             object
# poblaci_n_5_16                 float64
# tasa_matriculaci_n_5_16        float64
# cobertura_neta                 float64
# cobertura_neta_transici_n      float64
# cobertura_neta_primaria        float64
# cobertura_neta_secundaria      float64
# cobertura_neta_media           float64
# cobertura_bruta                float64
# cobertura_bruta_transici_n     float64
# cobertura_bruta_primaria       float64
# cobertura_bruta_secundaria     float64
# cobertura_bruta_media          float64
# deserci_n                      float64
# deserci_n_transici_n           float64
# deserci_n_primaria             float64
# deserci_n_secundaria           float64
# deserci_n_media                float64
# aprobaci_n                     float64
# aprobaci_n_transici_n          float64
# aprobaci_n_primaria            float64
# aprobaci_n_secundaria          float64
# aprobaci_n_media               float64
# reprobaci_n                    float64
# reprobaci_n_transici_n         float64
# reprobaci_n_primaria           float64
# reprobaci_n_secundaria         float64
# reprobaci_n_media              float64
# repitencia                     float64
# repitencia_transici_n          float64
# repitencia_primaria            float64
# repitencia_secundaria          float64
# repitencia_media               float64
# tama_o_promedio_de_grupo       float64
# sedes_conectadas_a_internet    float64
# index                            int64
# departamento                    object
# dtype: object

# %%
## departamento despues de codigo departamento

# lista de columnas
cols = df_raw.columns.tolist()

# reorganizar colocando 'departamento' después de 'c_digo_departamento'
cols.remove('departamento')
pos = cols.index('c_digo_departamento') + 1
cols.insert(pos, 'departamento')

# Aplicar nuevo orden
df_raw = df_raw[cols]
df_raw
# Out:
#         a_o c_digo_municipio    municipio c_digo_departamento departamento  \
# 0      2023            05004     Abriaquí                  05    Antioquia
# 1      2023            95025   El Retorno                  95     Guaviare
# 2      2023            95200   Miraflores                  95     Guaviare
# 3      2023            97001         Mitú                  97       Vaupés
# 4      2023            97161       Caruru                  97       Vaupés
# ...     ...              ...          ...                 ...          ...
# 14577  2011            05036  Angelópolis                  05    Antioquia
# 14578  2011            05034        Andes                  05    Antioquia
# 14579  2011            05031       Amalfi                  05    Antioquia
# 14580  2011            05030        Amagá                  05    Antioquia
# 14581  2011            05021   Alejandría                  05    Antioquia
#
#        poblaci_n_5_16  tasa_matriculaci_n_5_16  cobertura_neta  \
# 0               503.0                    62.62           62.62
# 1              4438.0                    53.27           53.27
# 2              2014.0                    32.52           32.52
# 3             10986.0                    59.57           59.57
# 4              1228.0                    51.30           51.30
# ...               ...                      ...             ...
# 14577          1707.0                    78.85           78.90
# 14578         10244.0                    84.45           84.50
# 14579          5552.0                    97.71           97.70
# 14580          6631.0                    78.65           78.70
# 14581           702.0                   118.52          118.50
#
#        cobertura_neta_transici_n  cobertura_neta_primaria  \
# 0                          44.19                    63.33
# 1                          33.91                    48.89
# 2                          17.58                    25.33
# 3                          42.76                    55.95
# 4                          76.32                    52.29
# ...                          ...                      ...
# 14577                      56.20                    82.40
# 14578                      65.10                    83.70
# 14579                      61.70                   107.20
# 14580                      55.30                    76.30
# 14581                      82.70                   127.60
#
#        cobertura_neta_secundaria  cobertura_neta_media  cobertura_bruta  \
# 0                          51.53                 40.23            66.80
# 1                          44.90                 21.30            62.98
# 2                          26.43                 10.75            38.58
# 3                          43.51                 17.06            70.65
# 4                          33.71                 11.94            55.54
# ...                          ...                   ...              ...
# 14577                      59.90                 26.40            82.80
# 14578                      62.00                 32.20            91.70
# 14579                      65.10                 27.30           108.40
# 14580                      70.70                 38.90            87.70
# 14581                      90.20                 48.50           134.90
#
#        cobertura_bruta_transici_n  cobertura_bruta_primaria  \
# 0                           58.14                     72.86
# 1                           54.20                     65.19
# 2                           36.36                     37.28
# 3                           64.90                     76.96
# 4                           92.11                     65.21
# ...                           ...                       ...
# 14577                       77.40                    105.00
# 14578                       81.10                    107.50
# 14579                       77.90                    146.80
# 14580                       74.30                     89.80
# 14581                       86.50                    159.80
#
#        cobertura_bruta_secundaria  cobertura_bruta_media  deserci_n  \
# 0                           66.87                  56.32       1.19
# 1                           69.60                  48.54       5.56
# 2                           46.10                  26.16       7.85
# 3                           72.92                  53.12       3.95
# 4                           51.12                  27.36       8.36
# ...                           ...                    ...        ...
# 14577                       80.40                  40.10       8.14
# 14578                       89.90                  61.40       3.96
# 14579                       97.30                  53.90       8.75
# 14580                       96.30                  73.20       4.16
# 14581                      140.80                  94.00       4.03
#
#        deserci_n_transici_n  deserci_n_primaria  deserci_n_secundaria  \
# 0                      0.00                1.31                  0.00
# 1                      6.95                4.99                  6.11
# 2                     15.00                8.43                  6.36
# 3                      2.27                1.84                  6.77
# 4                      4.29                3.05                 15.72
# ...                     ...                 ...                   ...
# 14577                  6.60                6.10                 13.17
# 14578                  3.06                4.30                  4.36
# 14579                  5.83                8.59                  9.49
# 14580                  2.39                3.23                  6.12
# 14581                   NaN                 NaN                  8.46
#
#        deserci_n_media  aprobaci_n  aprobaci_n_transici_n  \
# 0                 4.08       92.26                   0.00
# 1                 5.26       87.67                   0.00
# 2                 4.69       82.68                   3.33
# 3                 5.47       90.71                   0.57
# 4                14.55       82.40                   0.00
# ...                ...         ...                    ...
# 14577             2.44       86.27                   0.00
# 14578             1.68       95.46                   0.00
# 14579             9.74       91.25                   0.00
# 14580             3.21       86.86                   0.24
# 14581             8.04       92.39                   0.00
#
#        aprobaci_n_primaria  aprobaci_n_secundaria  aprobaci_n_media  \
# 0                    96.73                  83.49             93.88
# 1                    87.90                  84.50             92.98
# 2                    84.64                  79.51             87.50
# 3                    94.12                  84.91             89.93
# 4                    89.63                  69.00             78.18
# ...                    ...                    ...               ...
# 14577                90.29                  77.32             90.24
# 14578                95.12                  95.61             95.63
# 14579                91.41                  90.51             90.26
# 14580                90.04                  79.42             89.34
# 14581                97.84                  87.15             83.93
#
#        reprobaci_n  reprobaci_n_transici_n  reprobaci_n_primaria  \
# 0             6.55                    0.00                  1.96
# 1             6.78                    0.00                  7.11
# 2             9.47                    3.33                  6.93
# 3             5.34                    0.57                  4.04
# 4             9.24                    0.00                  7.32
# ...            ...                     ...                   ...
# 14577         5.59                    0.00                  3.61
# 14578         0.58                    0.00                  0.58
# 14579         0.00                    0.00                  0.00
# 14580         8.99                    0.24                  6.73
# 14581         3.58                    0.00                  2.16
#
#        reprobaci_n_secundaria  reprobaci_n_media  repitencia  \
# 0                       16.51               2.04        9.52
# 1                        9.39               1.75        9.34
# 2                       14.13               7.81        8.65
# 3                        8.33               4.60       16.18
# 4                       15.28               7.27        9.24
# ...                       ...                ...         ...
# 14577                    9.50               7.32        0.71
# 14578                    0.04               2.69        5.41
# 14579                    0.00               0.00         NaN
# 14580                   14.46               7.45        0.42
# 14581                    4.39               8.04        0.60
#
#        repitencia_transici_n  repitencia_primaria  repitencia_secundaria  \
# 0                       0.00                10.46                  13.76
# 1                       6.95                11.84                   8.48
# 2                       6.67                 9.04                  10.25
# 3                       7.75                21.04                  13.84
# 4                       2.86                 7.62                  14.85
# ...                      ...                  ...                    ...
# 14577                   0.00                 0.70                   1.08
# 14578                   0.73                 5.53                   6.90
# 14579                   0.83                  NaN                   9.93
# 14580                   0.00                 0.24                   0.91
# 14581                   0.00                 0.96                   0.00
#
#        repitencia_media  tama_o_promedio_de_grupo  \
# 0                  2.04                       NaN
# 1                  3.16                       NaN
# 2                  1.54                       NaN
# 3                  7.18                       NaN
# 4                  3.64                       NaN
# ...                 ...                       ...
# 14577              0.00                     19.57
# 14578              4.11                     24.43
# 14579              4.47                     20.01
# 14580              0.00                     25.05
# 14581              0.00                     32.14
#
#        sedes_conectadas_a_internet  index
# 0                              NaN      0
# 1                              NaN      1
# 2                              NaN      1
# 3                              NaN      3
# 4                              NaN      3
# ...                            ...    ...
# 14577                       100.00      0
# 14578                        93.44      0
# 14579                        53.45      0
# 14580                        83.33      0
# 14581                        81.25      0
#
# [14582 rows x 40 columns]

# %% [markdown]
# ### Faltantes, eliminar los que tienen muchos datos faltantes

# %%
df_raw.isnull().sum().sort_values(ascending=False)
# Out:
# tama_o_promedio_de_grupo       7010
# sedes_conectadas_a_internet    6814
# deserci_n_transici_n            903
# deserci_n_media                 734
# deserci_n_secundaria            270
# deserci_n_primaria              242
# repitencia_transici_n           159
# repitencia_secundaria           152
# repitencia_primaria             148
# reprobaci_n_media               145
# repitencia                      143
# deserci_n                       142
# repitencia_media                139
# cobertura_bruta_media           127
# tasa_matriculaci_n_5_16         115
# cobertura_neta                  111
# reprobaci_n_secundaria          106
# aprobaci_n_media                101
# reprobaci_n_primaria             97
# cobertura_bruta_transici_n       97
# cobertura_neta_secundaria        94
# aprobaci_n_transici_n            93
# cobertura_neta_media             93
# reprobaci_n_transici_n           93
# cobertura_neta_primaria          91
# cobertura_bruta_secundaria       88
# reprobaci_n                      86
# cobertura_bruta_primaria         81
# cobertura_bruta                  68
# aprobaci_n_secundaria            54
# cobertura_neta_transici_n        52
# aprobaci_n                       25
# aprobaci_n_primaria              25
# poblaci_n_5_16                    6
# departamento                      0
# c_digo_departamento               0
# a_o                               0
# c_digo_municipio                  0
# municipio                         0
# index                             0
# dtype: int64

# %%
# Eliminar columnas con demasiados nulos 
df_raw.drop(columns=['tama_o_promedio_de_grupo', 'sedes_conectadas_a_internet', 'deserci_n_transici_n', 'deserci_n_media'], inplace=True)
df_raw.head(3)
# Out:
#     a_o c_digo_municipio   municipio c_digo_departamento departamento  \
# 0  2023            05004    Abriaquí                  05    Antioquia
# 1  2023            95025  El Retorno                  95     Guaviare
# 2  2023            95200  Miraflores                  95     Guaviare
#
#    poblaci_n_5_16  tasa_matriculaci_n_5_16  cobertura_neta  \
# 0           503.0                    62.62           62.62
# 1          4438.0                    53.27           53.27
# 2          2014.0                    32.52           32.52
#
#    cobertura_neta_transici_n  cobertura_neta_primaria  \
# 0                      44.19                    63.33
# 1                      33.91                    48.89
# 2                      17.58                    25.33
#
#    cobertura_neta_secundaria  cobertura_neta_media  cobertura_bruta  \
# 0                      51.53                 40.23            66.80
# 1                      44.90                 21.30            62.98
# 2                      26.43                 10.75            38.58
#
#    cobertura_bruta_transici_n  cobertura_bruta_primaria  \
# 0                       58.14                     72.86
# 1                       54.20                     65.19
# 2                       36.36                     37.28
#
#    cobertura_bruta_secundaria  cobertura_bruta_media  deserci_n  \
# 0                       66.87                  56.32       1.19
# 1                       69.60                  48.54       5.56
# 2                       46.10                  26.16       7.85
#
#    deserci_n_primaria  deserci_n_secundaria  aprobaci_n  \
# 0                1.31                  0.00       92.26
# 1                4.99                  6.11       87.67
# 2                8.43                  6.36       82.68
#
#    aprobaci_n_transici_n  aprobaci_n_primaria  aprobaci_n_secundaria  \
# 0                   0.00                96.73                  83.49
# 1                   0.00                87.90                  84.50
# 2                   3.33                84.64                  79.51
#
#    aprobaci_n_media  reprobaci_n  reprobaci_n_transici_n  \
# 0             93.88         6.55                    0.00
# 1             92.98         6.78                    0.00
# 2             87.50         9.47                    3.33
#
#    reprobaci_n_primaria  reprobaci_n_secundaria  reprobaci_n_media  \
# 0                  1.96                   16.51               2.04
# 1                  7.11                    9.39               1.75
# 2                  6.93                   14.13               7.81
#
#    repitencia  repitencia_transici_n  repitencia_primaria  \
# 0        9.52                   0.00                10.46
# 1        9.34                   6.95                11.84
# 2        8.65                   6.67                 9.04
#
#    repitencia_secundaria  repitencia_media  index
# 0                  13.76              2.04      0
# 1                   8.48              3.16      1
# 2                  10.25              1.54      1

# %%
df_raw = df_raw.copy()

# %%
### imputar faltantes con mediana

imputacion_mediana = [
    'deserci_n_secundaria', 'deserci_n_primaria', 'repitencia_transici_n', 'repitencia_secundaria', 
    'repitencia_primaria', 'reprobaci_n_media', 'repitencia', 'deserci_n', 'repitencia_media', 
    'cobertura_bruta_media', 'tasa_matriculaci_n_5_16', 'cobertura_neta', 'reprobaci_n_secundaria', 
    'aprobaci_n_media', 'cobertura_bruta_transici_n', 'reprobaci_n_primaria', 'cobertura_neta_secundaria', 
    'cobertura_neta_media', 'reprobaci_n_transici_n', 'aprobaci_n_transici_n', 'cobertura_neta_primaria', 
    'cobertura_bruta_secundaria', 'reprobaci_n', 'cobertura_bruta_primaria', 'cobertura_bruta', 
    'aprobaci_n_secundaria', 'cobertura_neta_transici_n', 'aprobaci_n_primaria', 'aprobaci_n', 
    'poblaci_n_5_16'
]

for col in imputacion_mediana:
    df_raw[col] = df_raw[col].fillna(df_raw[col].median())

# %%
## Prueba
### Valores nulos
df_raw.isnull().sum().sort_values(ascending=False)
# Out:
# a_o                           0
# c_digo_municipio              0
# municipio                     0
# c_digo_departamento           0
# departamento                  0
# poblaci_n_5_16                0
# tasa_matriculaci_n_5_16       0
# cobertura_neta                0
# cobertura_neta_transici_n     0
# cobertura_neta_primaria       0
# cobertura_neta_secundaria     0
# cobertura_neta_media          0
# cobertura_bruta               0
# cobertura_bruta_transici_n    0
# cobertura_bruta_primaria      0
# cobertura_bruta_secundaria    0
# cobertura_bruta_media         0
# deserci_n                     0
# deserci_n_primaria            0
# deserci_n_secundaria          0
# aprobaci_n                    0
# aprobaci_n_transici_n         0
# aprobaci_n_primaria           0
# aprobaci_n_secundaria         0
# aprobaci_n_media              0
# reprobaci_n                   0
# reprobaci_n_transici_n        0
# reprobaci_n_primaria          0
# reprobaci_n_secundaria        0
# reprobaci_n_media             0
# repitencia                    0
# repitencia_transici_n         0
# repitencia_primaria           0
# repitencia_secundaria         0
# repitencia_media              0
# index                         0
# dtype: int64

# %%
df_raw[imputacion_mediana].describe()
# Out:
#        deserci_n_secundaria  deserci_n_primaria  repitencia_transici_n  \
# count          14582.000000        14582.000000           14582.000000
# mean               4.568885            2.749975               0.933135
# std                3.074556            2.031311               2.404131
# min                0.000000            0.000000               0.000000
# 25%                2.380000            1.280000               0.000000
# 50%                4.040000            2.320000               0.000000
# 75%                6.150000            3.750000               0.920000
# max               47.140000           18.310000              50.000000
#
#        repitencia_secundaria  repitencia_primaria  reprobaci_n_media  \
# count           14582.000000         14582.000000       14582.000000
# mean                4.310828             3.157061           4.121498
# std                 4.527894             3.627971           4.192027
# min                 0.000000             0.000000           0.000000
# 25%                 0.750000             0.600000           0.682500
# 50%                 2.740000             1.880000           3.110000
# 75%                 6.770000             4.550000           6.360000
# max                55.070000            50.760000          67.860000
#
#          repitencia     deserci_n  repitencia_media  cobertura_bruta_media  \
# count  14582.000000  14582.000000      14582.000000           14582.000000
# mean       3.288975      3.487122          1.690343              75.865937
# std        3.355109      2.161911          2.274741              26.856202
# min        0.000000      0.000000          0.000000               0.000000
# 25%        0.730000      1.950000          0.000000              59.760000
# 50%        2.160000      3.130000          0.870000              75.250000
# 75%        5.047500      4.640000          2.530000              90.240000
# max       37.470000     27.900000         36.450000             489.620000
#
#        tasa_matriculaci_n_5_16  cobertura_neta  reprobaci_n_secundaria  \
# count             14582.000000    14582.000000            14582.000000
# mean                 84.992045       85.577053                6.805669
# std                  18.478310       16.825936                6.131181
# min                   0.000000        0.000000                0.000000
# 25%                  74.950000       76.962500                0.762500
# 50%                  85.330000       86.400000                6.160000
# 75%                  95.307500       94.477500               10.790000
# max                 279.030000      264.540000               76.970000
#
#        aprobaci_n_media  cobertura_bruta_transici_n  reprobaci_n_primaria  \
# count      14582.000000                14582.000000          14582.000000
# mean          92.167227                   87.135333              3.881868
# std            6.867764                   25.453826              3.790051
# min            0.000000                    0.000000              0.000000
# 25%           89.470000                   71.560000              0.430000
# 50%           93.290000                   85.220000              3.330000
# 75%           96.410000                  100.000000              5.980000
# max          100.000000                  259.290000             51.970000
#
#        cobertura_neta_secundaria  cobertura_neta_media  \
# count               14582.000000          14582.000000
# mean                   69.926184             40.758024
# std                    18.746043             15.570022
# min                     0.000000              0.000000
# 25%                    60.500000             31.192500
# 50%                    70.900000             41.180000
# 75%                    80.500000             50.500000
# max                   229.440000            170.260000
#
#        reprobaci_n_transici_n  aprobaci_n_transici_n  cobertura_neta_primaria  \
# count            14582.000000           14582.000000             14582.000000
# mean                 0.483803               0.483803                82.585241
# std                  1.648629               1.648629                17.111552
# min                  0.000000               0.000000                 0.000000
# 25%                  0.000000               0.000000                73.310000
# 50%                  0.000000               0.000000                82.840000
# 75%                  0.210000               0.210000                91.867500
# max                 52.710000              52.710000               254.960000
#
#        cobertura_bruta_secundaria   reprobaci_n  cobertura_bruta_primaria  \
# count                14582.000000  14582.000000              14582.000000
# mean                   101.135100      4.756870                105.093967
# std                     25.708737      3.987597                 25.174776
# min                      0.000000      0.000000                  0.000000
# 25%                     86.642500      0.950000                 89.910000
# 50%                    101.535000      4.520000                103.320000
# 75%                    115.630000      7.397500                117.600000
# max                    301.710000     49.390000                326.400000
#
#        cobertura_bruta  aprobaci_n_secundaria  cobertura_neta_transici_n  \
# count     14582.000000           14582.000000               14582.000000
# mean         97.579165              88.379478                  57.704857
# std          21.208524               7.858355                  16.150646
# min           0.000000               0.000000                   0.000000
# 25%          85.730000              83.660000                  47.590000
# 50%          97.490000              89.100000                  57.900000
# 75%         109.190000              94.440000                  68.000000
# max         286.920000             100.000000                 150.470000
#
#        aprobaci_n_primaria    aprobaci_n  poblaci_n_5_16
# count         14582.000000  14582.000000    1.458200e+04
# mean             93.233581     91.627448    8.302304e+03
# std               5.041247      5.162328    4.556071e+04
# min               0.000000      0.000000    1.000000e+00
# 25%              90.580000     88.450000    1.165000e+03
# 50%              93.870000     92.020000    2.639000e+03
# 75%              96.940000     95.580000    5.862750e+03
# max             100.000000    100.000000    1.479334e+06

# %% [markdown]
# - Las variables relacionadas con cobertura educativa y tasa de matrícula pueden superar el 100% debido a factores como extraedad (estudiantes fuera de la edad teórica para un nivel educativo) y flujos migratorios no capturados en las proyecciones de población. Esto es común en áreas con alta demanda social o movimientos poblacionales.

# %% [markdown]
# ### Necesito crear la variable: `total matriculados`

# %%
df_raw['total_matriculados'] = df_raw['poblaci_n_5_16'] * df_raw['tasa_matriculaci_n_5_16']
df_raw.head(3)
# Out:
#     a_o c_digo_municipio   municipio c_digo_departamento departamento  \
# 0  2023            05004    Abriaquí                  05    Antioquia
# 1  2023            95025  El Retorno                  95     Guaviare
# 2  2023            95200  Miraflores                  95     Guaviare
#
#    poblaci_n_5_16  tasa_matriculaci_n_5_16  cobertura_neta  \
# 0           503.0                    62.62           62.62
# 1          4438.0                    53.27           53.27
# 2          2014.0                    32.52           32.52
#
#    cobertura_neta_transici_n  cobertura_neta_primaria  \
# 0                      44.19                    63.33
# 1                      33.91                    48.89
# 2                      17.58                    25.33
#
#    cobertura_neta_secundaria  cobertura_neta_media  cobertura_bruta  \
# 0                      51.53                 40.23            66.80
# 1                      44.90                 21.30            62.98
# 2                      26.43                 10.75            38.58
#
#    cobertura_bruta_transici_n  cobertura_bruta_primaria  \
# 0                       58.14                     72.86
# 1                       54.20                     65.19
# 2                       36.36                     37.28
#
#    cobertura_bruta_secundaria  cobertura_bruta_media  deserci_n  \
# 0                       66.87                  56.32       1.19
# 1                       69.60                  48.54       5.56
# 2                       46.10                  26.16       7.85
#
#    deserci_n_primaria  deserci_n_secundaria  aprobaci_n  \
# 0                1.31                  0.00       92.26
# 1                4.99                  6.11       87.67
# 2                8.43                  6.36       82.68
#
#    aprobaci_n_transici_n  aprobaci_n_primaria  aprobaci_n_secundaria  \
# 0                   0.00                96.73                  83.49
# 1                   0.00                87.90                  84.50
# 2                   3.33                84.64                  79.51
#
#    aprobaci_n_media  reprobaci_n  reprobaci_n_transici_n  \
# 0             93.88         6.55                    0.00
# 1             92.98         6.78                    0.00
# 2             87.50         9.47                    3.33
#
#    reprobaci_n_primaria  reprobaci_n_secundaria  reprobaci_n_media  \
# 0                  1.96                   16.51               2.04
# 1                  7.11                    9.39               1.75
# 2                  6.93                   14.13               7.81
#
#    repitencia  repitencia_transici_n  repitencia_primaria  \
# 0        9.52                   0.00                10.46
# 1        9.34                   6.95                11.84
# 2        8.65                   6.67                 9.04
#
#    repitencia_secundaria  repitencia_media  index  total_matriculados
# 0                  13.76              2.04      0            31497.86
# 1                   8.48              3.16      1           236412.26
# 2                  10.25              1.54      1            65495.28

# %%
## ordenar tablas 

columnas_orden = list(df_raw.columns)
columnas_orden.insert(6, columnas_orden.pop(columnas_orden.index('total_matriculados')))

df_raw = df_raw[columnas_orden]
df_raw.head(3)
# Out:
#     a_o c_digo_municipio   municipio c_digo_departamento departamento  \
# 0  2023            05004    Abriaquí                  05    Antioquia
# 1  2023            95025  El Retorno                  95     Guaviare
# 2  2023            95200  Miraflores                  95     Guaviare
#
#    poblaci_n_5_16  total_matriculados  tasa_matriculaci_n_5_16  \
# 0           503.0            31497.86                    62.62
# 1          4438.0           236412.26                    53.27
# 2          2014.0            65495.28                    32.52
#
#    cobertura_neta  cobertura_neta_transici_n  cobertura_neta_primaria  \
# 0           62.62                      44.19                    63.33
# 1           53.27                      33.91                    48.89
# 2           32.52                      17.58                    25.33
#
#    cobertura_neta_secundaria  cobertura_neta_media  cobertura_bruta  \
# 0                      51.53                 40.23            66.80
# 1                      44.90                 21.30            62.98
# 2                      26.43                 10.75            38.58
#
#    cobertura_bruta_transici_n  cobertura_bruta_primaria  \
# 0                       58.14                     72.86
# 1                       54.20                     65.19
# 2                       36.36                     37.28
#
#    cobertura_bruta_secundaria  cobertura_bruta_media  deserci_n  \
# 0                       66.87                  56.32       1.19
# 1                       69.60                  48.54       5.56
# 2                       46.10                  26.16       7.85
#
#    deserci_n_primaria  deserci_n_secundaria  aprobaci_n  \
# 0                1.31                  0.00       92.26
# 1                4.99                  6.11       87.67
# 2                8.43                  6.36       82.68
#
#    aprobaci_n_transici_n  aprobaci_n_primaria  aprobaci_n_secundaria  \
# 0                   0.00                96.73                  83.49
# 1                   0.00                87.90                  84.50
# 2                   3.33                84.64                  79.51
#
#    aprobaci_n_media  reprobaci_n  reprobaci_n_transici_n  \
# 0             93.88         6.55                    0.00
# 1             92.98         6.78                    0.00
# 2             87.50         9.47                    3.33
#
#    reprobaci_n_primaria  reprobaci_n_secundaria  reprobaci_n_media  \
# 0                  1.96                   16.51               2.04
# 1                  7.11                    9.39               1.75
# 2                  6.93                   14.13               7.81
#
#    repitencia  repitencia_transici_n  repitencia_primaria  \
# 0        9.52                   0.00                10.46
# 1        9.34                   6.95                11.84
# 2        8.65                   6.67                 9.04
#
#    repitencia_secundaria  repitencia_media  index
# 0                  13.76              2.04      0
# 1                   8.48              3.16      1
# 2                  10.25              1.54      1

# %%
nuevos_nombres = {
    'a_o': 'anio',
    'c_digo_municipio': 'codigo_municipio',
    'municipio': 'nombre_municipio',
    'c_digo_departamento': 'codigo_departamento',
    'departamento': 'nombre_departamento',
    'poblaci_n_5_16': 'poblacion_5_16',
    'total_matriculados': 'total_matriculados',
    'tasa_matriculaci_n_5_16': 'tasa_matriculacion_5_16',
    'cobertura_neta': 'cobertura_neta_total',
    'cobertura_neta_transici_n': 'cobertura_neta_transicion',
    'cobertura_neta_primaria': 'cobertura_neta_primaria',
    'cobertura_neta_secundaria': 'cobertura_neta_secundaria',
    'cobertura_neta_media': 'cobertura_neta_media',
    'cobertura_bruta': 'cobertura_bruta_total',
    'cobertura_bruta_transici_n': 'cobertura_bruta_transicion',
    'cobertura_bruta_primaria': 'cobertura_bruta_primaria',
    'cobertura_bruta_secundaria': 'cobertura_bruta_secundaria',
    'cobertura_bruta_media': 'cobertura_bruta_media',
    'deserci_n': 'tasa_desercion_total',
    'deserci_n_primaria': 'tasa_desercion_primaria',
    'deserci_n_secundaria': 'tasa_desercion_secundaria',
    'aprobaci_n': 'tasa_aprobacion_total',
    'aprobaci_n_transici_n': 'tasa_aprobacion_transicion',
    'aprobaci_n_primaria': 'tasa_aprobacion_primaria',
    'aprobaci_n_secundaria': 'tasa_aprobacion_secundaria',
    'aprobaci_n_media': 'tasa_aprobacion_media',
    'reprobaci_n': 'tasa_reprobacion_total',
    'reprobaci_n_transici_n': 'tasa_reprobacion_transicion',
    'reprobaci_n_primaria': 'tasa_reprobacion_primaria',
    'reprobaci_n_secundaria': 'tasa_reprobacion_secundaria',
    'reprobaci_n_media': 'tasa_reprobacion_media',
    'repitencia': 'tasa_repitencia_total',
    'repitencia_transici_n': 'tasa_repitencia_transicion',
    'repitencia_primaria': 'tasa_repitencia_primaria',
    'repitencia_secundaria': 'tasa_repitencia_secundaria',
    'repitencia_media': 'tasa_repitencia_media'
}

df_raw.rename(columns=nuevos_nombres, inplace=True) ## aca renombra
df_raw.head(2)
# Out:
#    anio codigo_municipio nombre_municipio codigo_departamento  \
# 0  2023            05004         Abriaquí                  05
# 1  2023            95025       El Retorno                  95
#
#   nombre_departamento  poblacion_5_16  total_matriculados  \
# 0           Antioquia           503.0            31497.86
# 1            Guaviare          4438.0           236412.26
#
#    tasa_matriculacion_5_16  cobertura_neta_total  cobertura_neta_transicion  \
# 0                    62.62                 62.62                      44.19
# 1                    53.27                 53.27                      33.91
#
#    cobertura_neta_primaria  cobertura_neta_secundaria  cobertura_neta_media  \
# 0                    63.33                      51.53                 40.23
# 1                    48.89                      44.90                 21.30
#
#    cobertura_bruta_total  cobertura_bruta_transicion  \
# 0                  66.80                       58.14
# 1                  62.98                       54.20
#
#    cobertura_bruta_primaria  cobertura_bruta_secundaria  \
# 0                     72.86                       66.87
# 1                     65.19                       69.60
#
#    cobertura_bruta_media  tasa_desercion_total  tasa_desercion_primaria  \
# 0                  56.32                  1.19                     1.31
# 1                  48.54                  5.56                     4.99
#
#    tasa_desercion_secundaria  tasa_aprobacion_total  \
# 0                       0.00                  92.26
# 1                       6.11                  87.67
#
#    tasa_aprobacion_transicion  tasa_aprobacion_primaria  \
# 0                         0.0                     96.73
# 1                         0.0                     87.90
#
#    tasa_aprobacion_secundaria  tasa_aprobacion_media  tasa_reprobacion_total  \
# 0                       83.49                  93.88                    6.55
# 1                       84.50                  92.98                    6.78
#
#    tasa_reprobacion_transicion  tasa_reprobacion_primaria  \
# 0                          0.0                       1.96
# 1                          0.0                       7.11
#
#    tasa_reprobacion_secundaria  tasa_reprobacion_media  tasa_repitencia_total  \
# 0                        16.51                    2.04                   9.52
# 1                         9.39                    1.75                   9.34
#
#    tasa_repitencia_transicion  tasa_repitencia_primaria  \
# 0                        0.00                     10.46
# 1                        6.95                     11.84
#
#    tasa_repitencia_secundaria  tasa_repitencia_media  index
# 0                       13.76                   2.04      0
# 1                        8.48                   3.16      1

# %%
df_raw.dtypes
# Out:
# anio                            object
# codigo_municipio                object
# nombre_municipio                object
# codigo_departamento             object
# nombre_departamento             object
# poblacion_5_16                 float64
# total_matriculados             float64
# tasa_matriculacion_5_16        float64
# cobertura_neta_total           float64
# cobertura_neta_transicion      float64
# cobertura_neta_primaria        float64
# cobertura_neta_secundaria      float64
# cobertura_neta_media           float64
# cobertura_bruta_total          float64
# cobertura_bruta_transicion     float64
# cobertura_bruta_primaria       float64
# cobertura_bruta_secundaria     float64
# cobertura_bruta_media          float64
# tasa_desercion_total           float64
# tasa_desercion_primaria        float64
# tasa_desercion_secundaria      float64
# tasa_aprobacion_total          float64
# tasa_aprobacion_transicion     float64
# tasa_aprobacion_primaria       float64
# tasa_aprobacion_secundaria     float64
# tasa_aprobacion_media          float64
# tasa_reprobacion_total         float64
# tasa_reprobacion_transicion    float64
# tasa_reprobacion_primaria      float64
# tasa_reprobacion_secundaria    float64
# tasa_reprobacion_media         float64
# tasa_repitencia_total          float64
# tasa_repitencia_transicion     float64
# tasa_repitencia_primaria       float64
# tasa_repitencia_secundaria     float64
# tasa_repitencia_media          float64
# index                            int64
# dtype: object

# %% [markdown]
# ### Llave ID municipio año

# %%
df_raw['id_municipio_anio'] = df_raw['codigo_municipio'].astype(str).str.zfill(5) + "_" + df_raw['anio'].astype(str)
df_raw.set_index('id_municipio_anio', inplace=True) ## ponerlo como index
df_raw.head(3)
# Out:
#                    anio codigo_municipio nombre_municipio codigo_departamento  \
# id_municipio_anio
# 05004_2023         2023            05004         Abriaquí                  05
# 95025_2023         2023            95025       El Retorno                  95
# 95200_2023         2023            95200       Miraflores                  95
#
#                   nombre_departamento  poblacion_5_16  total_matriculados  \
# id_municipio_anio
# 05004_2023                  Antioquia           503.0            31497.86
# 95025_2023                   Guaviare          4438.0           236412.26
# 95200_2023                   Guaviare          2014.0            65495.28
#
#                    tasa_matriculacion_5_16  cobertura_neta_total  \
# id_municipio_anio
# 05004_2023                           62.62                 62.62
# 95025_2023                           53.27                 53.27
# 95200_2023                           32.52                 32.52
#
#                    cobertura_neta_transicion  cobertura_neta_primaria  \
# id_municipio_anio
# 05004_2023                             44.19                    63.33
# 95025_2023                             33.91                    48.89
# 95200_2023                             17.58                    25.33
#
#                    cobertura_neta_secundaria  cobertura_neta_media  \
# id_municipio_anio
# 05004_2023                             51.53                 40.23
# 95025_2023                             44.90                 21.30
# 95200_2023                             26.43                 10.75
#
#                    cobertura_bruta_total  cobertura_bruta_transicion  \
# id_municipio_anio
# 05004_2023                         66.80                       58.14
# 95025_2023                         62.98                       54.20
# 95200_2023                         38.58                       36.36
#
#                    cobertura_bruta_primaria  cobertura_bruta_secundaria  \
# id_municipio_anio
# 05004_2023                            72.86                       66.87
# 95025_2023                            65.19                       69.60
# 95200_2023                            37.28                       46.10
#
#                    cobertura_bruta_media  tasa_desercion_total  \
# id_municipio_anio
# 05004_2023                         56.32                  1.19
# 95025_2023                         48.54                  5.56
# 95200_2023                         26.16                  7.85
#
#                    tasa_desercion_primaria  tasa_desercion_secundaria  \
# id_municipio_anio
# 05004_2023                            1.31                       0.00
# 95025_2023                            4.99                       6.11
# 95200_2023                            8.43                       6.36
#
#                    tasa_aprobacion_total  tasa_aprobacion_transicion  \
# id_municipio_anio
# 05004_2023                         92.26                        0.00
# 95025_2023                         87.67                        0.00
# 95200_2023                         82.68                        3.33
#
#                    tasa_aprobacion_primaria  tasa_aprobacion_secundaria  \
# id_municipio_anio
# 05004_2023                            96.73                       83.49
# 95025_2023                            87.90                       84.50
# 95200_2023                            84.64                       79.51
#
#                    tasa_aprobacion_media  tasa_reprobacion_total  \
# id_municipio_anio
# 05004_2023                         93.88                    6.55
# 95025_2023                         92.98                    6.78
# 95200_2023                         87.50                    9.47
#
#                    tasa_reprobacion_transicion  tasa_reprobacion_primaria  \
# id_municipio_anio
# 05004_2023                                0.00                       1.96
# 95025_2023                                0.00                       7.11
# 95200_2023                                3.33                       6.93
#
#                    tasa_reprobacion_secundaria  tasa_reprobacion_media  \
# id_municipio_anio
# 05004_2023                               16.51                    2.04
# 95025_2023                                9.39                    1.75
# 95200_2023                               14.13                    7.81
#
#                    tasa_repitencia_total  tasa_repitencia_transicion  \
# id_municipio_anio
# 05004_2023                          9.52                        0.00
# 95025_2023                          9.34                        6.95
# 95200_2023                          8.65                        6.67
#
#                    tasa_repitencia_primaria  tasa_repitencia_secundaria  \
# id_municipio_anio
# 05004_2023                            10.46                       13.76
# 95025_2023                            11.84                        8.48
# 95200_2023                             9.04                       10.25
#
#                    tasa_repitencia_media  index
# id_municipio_anio
# 05004_2023                          2.04      0
# 95025_2023                          3.16      1
# 95200_2023                          1.54      1

# %% [markdown]
# Respecto a la población del municipio ¿Que porcentaje de escolaridad hay?

# %% [markdown]
# ## Crear una bodega de datos
#
# En esta bodega de datos la idea ers "subir" ambos conjuntos de datos y procesarlos desde SQL.

# %%
import sqlite3

# %%
conn = sqlite3.connect('../Datos/educacion_wilmer.db')

# %%
cursor = conn.cursor()

# %%
datos_2005_2019 = pd.read_excel('../Datos/Datos_antes_pandemia.xlsx')
datos_2020_2035 = pd.read_excel('../Datos/Datos_despues_pandemia.xlsx')

# %%
datos_2005_2019.to_sql("informacion_antes_pandemia",conn)
datos_2020_2035.to_sql("informacion_despues_pandemia",conn)
# Out:
# 53856

# %%
consulta = """
SELECT COUNT(*) FROM informacion_antes_pandemia
"""
pd.read_sql_query(consulta, conn)
# Out:
#    COUNT(*)
# 0     50490

# %%
consulta = """

SELECT * FROM informacion_antes_pandemia
LIMIT 10
"""
pd.read_sql_query(consulta, conn)
# Out:
#    index  DP      DPNOM        DPMP  MPIO   AÑO  \
# 0      0   5  Antioquia    Medellín  5001  2005
# 1      1   5  Antioquia    Medellín  5001  2005
# 2      2   5  Antioquia    Medellín  5001  2005
# 3      3   5  Antioquia   Abejorral  5002  2005
# 4      4   5  Antioquia   Abejorral  5002  2005
# 5      5   5  Antioquia   Abejorral  5002  2005
# 6      6   5  Antioquia    Abriaquí  5004  2005
# 7      7   5  Antioquia    Abriaquí  5004  2005
# 8      8   5  Antioquia    Abriaquí  5004  2005
# 9      9   5  Antioquia  Alejandría  5021  2005
#
#                      ÁREA GEOGRÁFICA  Población
# 0                 Cabecera Municipal    1997763
# 1  Centros Poblados y Rural Disperso      48578
# 2                              Total    2046341
# 3                 Cabecera Municipal       7158
# 4  Centros Poblados y Rural Disperso      15784
# 5                              Total      22942
# 6                 Cabecera Municipal        723
# 7  Centros Poblados y Rural Disperso       1996
# 8                              Total       2719
# 9                 Cabecera Municipal       2137

# %% [markdown]
# ### Antes pandemia

# %%
consulta = """
CREATE TABLE informacion_antes_pandemia_limpia AS
SELECT
  CASE 
    WHEN LENGTH(CAST(DP AS TEXT)) = 1 THEN '0' || CAST(DP AS TEXT)
    ELSE CAST(DP AS TEXT)
  END AS c_digo_departamento,

  DPNOM,
  DPMP,

  CASE 
    WHEN LENGTH(CAST(MPIO AS TEXT)) = 4 THEN '0' || CAST(MPIO AS TEXT)
    ELSE CAST(MPIO AS TEXT)
  END AS c_digo_municipio,

  AÑO,
  "ÁREA GEOGRÁFICA",
  Población
FROM informacion_antes_pandemia;
"""

# Ejecutar la consulta
conn.execute(consulta)
conn.commit()

# Leer la nueva tabla 
pd.read_sql_query("SELECT * FROM informacion_antes_pandemia_limpia LIMIT 10", conn)
# Out:
#   c_digo_departamento      DPNOM        DPMP c_digo_municipio   AÑO  \
# 0                  05  Antioquia    Medellín            05001  2005
# 1                  05  Antioquia    Medellín            05001  2005
# 2                  05  Antioquia    Medellín            05001  2005
# 3                  05  Antioquia   Abejorral            05002  2005
# 4                  05  Antioquia   Abejorral            05002  2005
# 5                  05  Antioquia   Abejorral            05002  2005
# 6                  05  Antioquia    Abriaquí            05004  2005
# 7                  05  Antioquia    Abriaquí            05004  2005
# 8                  05  Antioquia    Abriaquí            05004  2005
# 9                  05  Antioquia  Alejandría            05021  2005
#
#                      ÁREA GEOGRÁFICA  Población
# 0                 Cabecera Municipal    1997763
# 1  Centros Poblados y Rural Disperso      48578
# 2                              Total    2046341
# 3                 Cabecera Municipal       7158
# 4  Centros Poblados y Rural Disperso      15784
# 5                              Total      22942
# 6                 Cabecera Municipal        723
# 7  Centros Poblados y Rural Disperso       1996
# 8                              Total       2719
# 9                 Cabecera Municipal       2137

# %%
## tipos de datos
estructura = pd.read_sql_query("PRAGMA table_info(informacion_antes_pandemia_limpia);", conn)

# mostrar solo nombre y tipo
estructura[['name', 'type']]
# Out:
#                   name  type
# 0  c_digo_departamento
# 1                DPNOM  TEXT
# 2                 DPMP  TEXT
# 3     c_digo_municipio
# 4                  AÑO   INT
# 5      ÁREA GEOGRÁFICA  TEXT
# 6            Población   INT

# %%
consulta_antes = """
CREATE TABLE informacion_antes_pandemia_tipos_corregidos AS
SELECT
  CAST(c_digo_departamento AS TEXT) AS codigo_departamento,
  DPNOM AS nombre_departamento,
  DPMP,
  CAST(c_digo_municipio AS TEXT) AS codigo_municipio,
  CAST(AÑO AS TEXT) AS anio,
  "ÁREA GEOGRÁFICA" AS area_geografica,
  CAST(Población AS REAL) AS poblacion_5_16
FROM informacion_antes_pandemia_limpia;
"""
conn.execute(consulta_antes)

# %%
## borrar la antigua y cambiar nombre 
conn.execute("DROP TABLE informacion_antes_pandemia_limpia;")
conn.execute("ALTER TABLE informacion_antes_pandemia_tipos_corregidos RENAME TO informacion_antes_pandemia_limpia;")

# %%
## tipos de datos
estructura = pd.read_sql_query("PRAGMA table_info(informacion_antes_pandemia_limpia);", conn)

# mostrar solo nombre y tipo
estructura[['name', 'type']]
# Out:
#                   name  type
# 0  codigo_departamento  TEXT
# 1  nombre_departamento  TEXT
# 2                 DPMP  TEXT
# 3     codigo_municipio  TEXT
# 4                 anio  TEXT
# 5      area_geografica  TEXT
# 6       poblacion_5_16  REAL

# %% [markdown]
# ### Despues pandemia

# %%
consulta1 = """
CREATE TABLE informacion_despues_pandemia_limpia AS
SELECT
  printf('%02d', DP) AS c_digo_departamento,
  DPNOM,
  DPMP,
  printf('%05d', MPIO) AS c_digo_municipio,
  AÑO,
  "ÁREA GEOGRÁFICA",
  Población
FROM informacion_despues_pandemia;
"""
conn.execute(consulta1)
conn.commit()

pd.read_sql_query("SELECT * FROM informacion_despues_pandemia_limpia LIMIT 10", conn)
# Out:
#   c_digo_departamento      DPNOM      DPMP c_digo_municipio   AÑO  \
# 0                  05  Antioquia  Medellín            05001  2020
# 1                  05  Antioquia  Medellín            05001  2020
# 2                  05  Antioquia  Medellín            05001  2020
# 3                  05  Antioquia  Medellín            05001  2021
# 4                  05  Antioquia  Medellín            05001  2021
# 5                  05  Antioquia  Medellín            05001  2021
# 6                  05  Antioquia  Medellín            05001  2022
# 7                  05  Antioquia  Medellín            05001  2022
# 8                  05  Antioquia  Medellín            05001  2022
# 9                  05  Antioquia  Medellín            05001  2023
#
#                      ÁREA GEOGRÁFICA  Población
# 0                 Cabecera Municipal    2476569
# 1  Centros Poblados y Rural Disperso      43023
# 2                              Total    2519592
# 3                 Cabecera Municipal    2506656
# 4  Centros Poblados y Rural Disperso      42352
# 5                              Total    2549008
# 6                 Cabecera Municipal    2530398
# 7  Centros Poblados y Rural Disperso      41952
# 8                              Total    2572350
# 9                 Cabecera Municipal    2553621

# %%
## tipos de datos
estructura1 = pd.read_sql_query("PRAGMA table_info(informacion_despues_pandemia_limpia);", conn)

# mostrar solo nombre y tipo
estructura1[['name', 'type']]
# Out:
#                   name  type
# 0  c_digo_departamento
# 1                DPNOM  TEXT
# 2                 DPMP  TEXT
# 3     c_digo_municipio
# 4                  AÑO   INT
# 5      ÁREA GEOGRÁFICA  TEXT
# 6            Población   INT

# %%
consulta_despues = """
CREATE TABLE informacion_despues_pandemia_tipos_corregidos AS
SELECT
  CAST(c_digo_departamento AS TEXT) AS codigo_departamento,
  DPNOM AS nombre_departamento,
  DPMP,
  CAST(c_digo_municipio AS TEXT) AS codigo_municipio,
  CAST(AÑO AS TEXT) AS anio,
  "ÁREA GEOGRÁFICA" AS area_geografica,
  CAST(Población AS REAL) AS poblacion_5_16
FROM informacion_despues_pandemia_limpia;
"""
conn.execute(consulta_despues)

# %%
conn.execute("DROP TABLE informacion_despues_pandemia_limpia;")
conn.execute("ALTER TABLE informacion_despues_pandemia_tipos_corregidos RENAME TO informacion_despues_pandemia_limpia;")
conn.commit()

# %%
## tipos de datos
estructura1 = pd.read_sql_query("PRAGMA table_info(informacion_despues_pandemia_limpia);", conn)

# mostrar solo nombre y tipo
estructura1[['name', 'type']]
# Out:
#                   name  type
# 0  codigo_departamento  TEXT
# 1  nombre_departamento  TEXT
# 2                 DPMP  TEXT
# 3     codigo_municipio  TEXT
# 4                 anio  TEXT
# 5      area_geografica  TEXT
# 6       poblacion_5_16  REAL

# %%
consulta_tablas= """
CREATE TABLE informacion_poblacion_total AS
SELECT * FROM informacion_antes_pandemia_limpia
UNION ALL
SELECT * FROM informacion_despues_pandemia_limpia;
"""

conn.execute(consulta_tablas)
conn.commit()

# %%
pd.read_sql_query("SELECT * FROM informacion_poblacion_total LIMIT 10;", conn) ## verificar
# Out:
#   codigo_departamento nombre_departamento        DPMP codigo_municipio  anio  \
# 0                  05           Antioquia    Medellín            05001  2005
# 1                  05           Antioquia    Medellín            05001  2005
# 2                  05           Antioquia    Medellín            05001  2005
# 3                  05           Antioquia   Abejorral            05002  2005
# 4                  05           Antioquia   Abejorral            05002  2005
# 5                  05           Antioquia   Abejorral            05002  2005
# 6                  05           Antioquia    Abriaquí            05004  2005
# 7                  05           Antioquia    Abriaquí            05004  2005
# 8                  05           Antioquia    Abriaquí            05004  2005
# 9                  05           Antioquia  Alejandría            05021  2005
#
#                      area_geografica  poblacion_5_16
# 0                 Cabecera Municipal       1997763.0
# 1  Centros Poblados y Rural Disperso         48578.0
# 2                              Total       2046341.0
# 3                 Cabecera Municipal          7158.0
# 4  Centros Poblados y Rural Disperso         15784.0
# 5                              Total         22942.0
# 6                 Cabecera Municipal           723.0
# 7  Centros Poblados y Rural Disperso          1996.0
# 8                              Total          2719.0
# 9                 Cabecera Municipal          2137.0

# %%
consulta_poblacion = """
CREATE TABLE poblacion_total_por_municipio AS
SELECT
  codigo_departamento,
  nombre_departamento,
  DPMP AS nombre_municipio,
  codigo_municipio,
  anio,
  poblacion_5_16 AS poblacion
FROM informacion_poblacion_total
WHERE area_geografica = 'Total';
"""

conn.execute(consulta_poblacion)
conn.commit()

# %%
pd.read_sql_query("SELECT * FROM poblacion_total_por_municipio LIMIT 10;", conn) ## verificar
# Out:
#   codigo_departamento nombre_departamento nombre_municipio codigo_municipio  \
# 0                  05           Antioquia         Medellín            05001
# 1                  05           Antioquia        Abejorral            05002
# 2                  05           Antioquia         Abriaquí            05004
# 3                  05           Antioquia       Alejandría            05021
# 4                  05           Antioquia            Amagá            05030
# 5                  05           Antioquia           Amalfi            05031
# 6                  05           Antioquia            Andes            05034
# 7                  05           Antioquia      Angelópolis            05036
# 8                  05           Antioquia        Angostura            05038
# 9                  05           Antioquia            Anorí            05040
#
#    anio  poblacion
# 0  2005  2046341.0
# 1  2005    22942.0
# 2  2005     2719.0
# 3  2005     4724.0
# 4  2005    27121.0
# 5  2005    22933.0
# 6  2005    41876.0
# 7  2005     5865.0
# 8  2005    12193.0
# 9  2005    15853.0

# %%
pd.read_sql_query("""
SELECT 
    MIN(CAST(anio AS INTEGER)) AS anio_min,
    MAX(CAST(anio AS INTEGER)) AS anio_max
FROM poblacion_total_por_municipio;
""", conn)
# Out:
#    anio_min  anio_max
# 0      2005      2035

# %%
pd.read_sql_query("""
SELECT DISTINCT anio
FROM poblacion_total_por_municipio
ORDER BY anio;
""", conn)
# Out:
#     anio
# 0   2005
# 1   2006
# 2   2007
# 3   2008
# 4   2009
# 5   2010
# 6   2011
# 7   2012
# 8   2013
# 9   2014
# 10  2015
# 11  2016
# 12  2017
# 13  2018
# 14  2019
# 15  2020
# 16  2021
# 17  2022
# 18  2023
# 19  2024
# 20  2025
# 21  2026
# 22  2027
# 23  2028
# 24  2029
# 25  2030
# 26  2031
# 27  2032
# 28  2033
# 29  2034
# 30  2035

# %%
## arreglar los años 

conn.execute("""
CREATE TABLE poblacion_total_limpia AS
SELECT 
  codigo_departamento,
  nombre_departamento,
  nombre_municipio,
  codigo_municipio,
  CAST(CAST(anio AS INTEGER) AS TEXT) AS anio,  -- ← esto elimina el .0
  poblacion
FROM poblacion_total_por_municipio;
""")
conn.commit()

# %%
## base de educacion abrirla en sql lite
df_raw.to_sql('df_raw', conn, if_exists='replace', index=False)
# Out:
# 14582

# %%
pd.read_sql_query("SELECT * FROM df_raw LIMIT 10;", conn)
# Out:
#    anio codigo_municipio nombre_municipio codigo_departamento  \
# 0  2023            05004         Abriaquí                  05
# 1  2023            95025       El Retorno                  95
# 2  2023            95200       Miraflores                  95
# 3  2023            97001             Mitú                  97
# 4  2023            97161           Caruru                  97
# 5  2023            97511            Pacoa                  97
# 6  2023            97666          Taraira                  97
# 7  2023            97777         Papunaua                  97
# 8  2023            97889         Yavaraté                  97
# 9  2023            99001   Puerto Carreño                  99
#
#   nombre_departamento  poblacion_5_16  total_matriculados  \
# 0           Antioquia           503.0            31497.86
# 1            Guaviare          4438.0           236412.26
# 2            Guaviare          2014.0            65495.28
# 3              Vaupés         10986.0           654436.02
# 4              Vaupés          1228.0            62996.40
# 5              Vaupés          1678.0            91098.62
# 6              Vaupés           814.0            18396.40
# 7              Vaupés           209.0                0.00
# 8              Vaupés           561.0            26899.95
# 9             Vichada          4641.0           670717.32
#
#    tasa_matriculacion_5_16  cobertura_neta_total  cobertura_neta_transicion  \
# 0                    62.62                 62.62                      44.19
# 1                    53.27                 53.27                      33.91
# 2                    32.52                 32.52                      17.58
# 3                    59.57                 59.57                      42.76
# 4                    51.30                 51.30                      76.32
# 5                    54.29                 54.29                      15.44
# 6                    22.60                 22.60                      14.29
# 7                     0.00                  0.00                       0.00
# 8                    47.95                 47.95                      68.75
# 9                   144.52                144.52                     114.44
#
#    cobertura_neta_primaria  cobertura_neta_secundaria  cobertura_neta_media  \
# 0                    63.33                      51.53                 40.23
# 1                    48.89                      44.90                 21.30
# 2                    25.33                      26.43                 10.75
# 3                    55.95                      43.51                 17.06
# 4                    52.29                      33.71                 11.94
# 5                    55.69                      24.91                  4.62
# 6                    34.98                       0.00                  0.00
# 7                     0.00                       0.00                  0.00
# 8                    52.19                      25.84                 13.04
# 9                   162.78                      78.48                 33.46
#
#    cobertura_bruta_total  cobertura_bruta_transicion  \
# 0                  66.80                       58.14
# 1                  62.98                       54.20
# 2                  38.58                       36.36
# 3                  70.65                       64.90
# 4                  55.54                       92.11
# 5                  71.39                       38.93
# 6                  23.34                       23.81
# 7                   0.00                        0.00
# 8                  52.05                      100.00
# 9                 158.50                      145.45
#
#    cobertura_bruta_primaria  cobertura_bruta_secundaria  \
# 0                     72.86                       66.87
# 1                     65.19                       69.60
# 2                     37.28                       46.10
# 3                     76.96                       72.92
# 4                     65.21                       51.12
# 5                    100.30                       67.92
# 6                     57.76                        0.00
# 7                      0.00                        0.00
# 8                     69.74                       36.36
# 9                    225.67                      122.55
#
#    cobertura_bruta_media  tasa_desercion_total  tasa_desercion_primaria  \
# 0                  56.32                  1.19                     1.31
# 1                  48.54                  5.56                     4.99
# 2                  26.16                  7.85                     8.43
# 3                  53.12                  3.95                     1.84
# 4                  27.36                  8.36                     3.05
# 5                  30.03                  5.35                     7.16
# 6                   0.00                  0.00                     0.00
# 7                   0.00                  0.00                     0.00
# 8                  27.17                  4.45                     1.89
# 9                  75.43                  5.81                     6.12
#
#    tasa_desercion_secundaria  tasa_aprobacion_total  \
# 0                       0.00                  92.26
# 1                       6.11                  87.67
# 2                       6.36                  82.68
# 3                       6.77                  90.71
# 4                      15.72                  82.40
# 5                       2.65                  94.65
# 6                       0.00                 100.00
# 7                       0.00                   0.00
# 8                       6.58                  95.55
# 9                       5.80                  80.93
#
#    tasa_aprobacion_transicion  tasa_aprobacion_primaria  \
# 0                        0.00                     96.73
# 1                        0.00                     87.90
# 2                        3.33                     84.64
# 3                        0.57                     94.12
# 4                        0.00                     89.63
# 5                        0.00                     92.84
# 6                        0.00                    100.00
# 7                        0.00                      0.00
# 8                        0.00                     98.11
# 9                        0.00                     80.92
#
#    tasa_aprobacion_secundaria  tasa_aprobacion_media  tasa_reprobacion_total  \
# 0                       83.49                  93.88                    6.55
# 1                       84.50                  92.98                    6.78
# 2                       79.51                  87.50                    9.47
# 3                       84.91                  89.93                    5.34
# 4                       69.00                  78.18                    9.24
# 5                       97.35                  93.41                    0.00
# 6                        0.00                   0.00                    0.00
# 7                        0.00                   0.00                    0.00
# 8                       93.42                  80.00                    0.00
# 9                       75.36                  87.89                   13.26
#
#    tasa_reprobacion_transicion  tasa_reprobacion_primaria  \
# 0                         0.00                       1.96
# 1                         0.00                       7.11
# 2                         3.33                       6.93
# 3                         0.57                       4.04
# 4                         0.00                       7.32
# 5                         0.00                       0.00
# 6                         0.00                       0.00
# 7                         0.00                       0.00
# 8                         0.00                       0.00
# 9                         0.00                      12.96
#
#    tasa_reprobacion_secundaria  tasa_reprobacion_media  tasa_repitencia_total  \
# 0                        16.51                    2.04                   9.52
# 1                         9.39                    1.75                   9.34
# 2                        14.13                    7.81                   8.65
# 3                         8.33                    4.60                  16.18
# 4                        15.28                    7.27                   9.24
# 5                         0.00                    0.00                  23.21
# 6                         0.00                    0.00                  21.58
# 7                         0.00                    0.00                   0.00
# 8                         0.00                    0.00                  12.33
# 9                        18.84                    8.81                  11.18
#
#    tasa_repitencia_transicion  tasa_repitencia_primaria  \
# 0                        0.00                     10.46
# 1                        6.95                     11.84
# 2                        6.67                      9.04
# 3                        7.75                     21.04
# 4                        2.86                      7.62
# 5                       25.86                     30.30
# 6                       13.33                     22.29
# 7                        0.00                      0.00
# 8                        3.13                     19.50
# 9                        0.82                     13.25
#
#    tasa_repitencia_secundaria  tasa_repitencia_media  index
# 0                       13.76                   2.04      0
# 1                        8.48                   3.16      1
# 2                       10.25                   1.54      1
# 3                       13.84                   7.18      3
# 4                       14.85                   3.64      3
# 5                       14.25                   6.59      3
# 6                        0.00                   0.00      3
# 7                        0.00                   0.00      3
# 8                        3.95                   4.00      3
# 9                       10.45                   6.39      9

# %%
consulta_union = """
CREATE TABLE educacion_final AS
SELECT 
    r.*,
    p.poblacion
FROM df_raw r
LEFT JOIN poblacion_total_limpia p
  ON r.codigo_municipio = p.codigo_municipio
  AND r.anio = p.anio;
"""
conn.execute(consulta_union)
conn.commit()

# %%
pd.read_sql_query("SELECT * FROM educacion_final LIMIT 10;", conn) ## verificar
# Out:
#    anio codigo_municipio nombre_municipio codigo_departamento  \
# 0  2023            05004         Abriaquí                  05
# 1  2023            95025       El Retorno                  95
# 2  2023            95200       Miraflores                  95
# 3  2023            97001             Mitú                  97
# 4  2023            97161           Caruru                  97
# 5  2023            97511            Pacoa                  97
# 6  2023            97666          Taraira                  97
# 7  2023            97777         Papunaua                  97
# 8  2023            97889         Yavaraté                  97
# 9  2023            99001   Puerto Carreño                  99
#
#   nombre_departamento  poblacion_5_16  total_matriculados  \
# 0           Antioquia           503.0            31497.86
# 1            Guaviare          4438.0           236412.26
# 2            Guaviare          2014.0            65495.28
# 3              Vaupés         10986.0           654436.02
# 4              Vaupés          1228.0            62996.40
# 5              Vaupés          1678.0            91098.62
# 6              Vaupés           814.0            18396.40
# 7              Vaupés           209.0                0.00
# 8              Vaupés           561.0            26899.95
# 9             Vichada          4641.0           670717.32
#
#    tasa_matriculacion_5_16  cobertura_neta_total  cobertura_neta_transicion  \
# 0                    62.62                 62.62                      44.19
# 1                    53.27                 53.27                      33.91
# 2                    32.52                 32.52                      17.58
# 3                    59.57                 59.57                      42.76
# 4                    51.30                 51.30                      76.32
# 5                    54.29                 54.29                      15.44
# 6                    22.60                 22.60                      14.29
# 7                     0.00                  0.00                       0.00
# 8                    47.95                 47.95                      68.75
# 9                   144.52                144.52                     114.44
#
#    cobertura_neta_primaria  cobertura_neta_secundaria  cobertura_neta_media  \
# 0                    63.33                      51.53                 40.23
# 1                    48.89                      44.90                 21.30
# 2                    25.33                      26.43                 10.75
# 3                    55.95                      43.51                 17.06
# 4                    52.29                      33.71                 11.94
# 5                    55.69                      24.91                  4.62
# 6                    34.98                       0.00                  0.00
# 7                     0.00                       0.00                  0.00
# 8                    52.19                      25.84                 13.04
# 9                   162.78                      78.48                 33.46
#
#    cobertura_bruta_total  cobertura_bruta_transicion  \
# 0                  66.80                       58.14
# 1                  62.98                       54.20
# 2                  38.58                       36.36
# 3                  70.65                       64.90
# 4                  55.54                       92.11
# 5                  71.39                       38.93
# 6                  23.34                       23.81
# 7                   0.00                        0.00
# 8                  52.05                      100.00
# 9                 158.50                      145.45
#
#    cobertura_bruta_primaria  cobertura_bruta_secundaria  \
# 0                     72.86                       66.87
# 1                     65.19                       69.60
# 2                     37.28                       46.10
# 3                     76.96                       72.92
# 4                     65.21                       51.12
# 5                    100.30                       67.92
# 6                     57.76                        0.00
# 7                      0.00                        0.00
# 8                     69.74                       36.36
# 9                    225.67                      122.55
#
#    cobertura_bruta_media  tasa_desercion_total  tasa_desercion_primaria  \
# 0                  56.32                  1.19                     1.31
# 1                  48.54                  5.56                     4.99
# 2                  26.16                  7.85                     8.43
# 3                  53.12                  3.95                     1.84
# 4                  27.36                  8.36                     3.05
# 5                  30.03                  5.35                     7.16
# 6                   0.00                  0.00                     0.00
# 7                   0.00                  0.00                     0.00
# 8                  27.17                  4.45                     1.89
# 9                  75.43                  5.81                     6.12
#
#    tasa_desercion_secundaria  tasa_aprobacion_total  \
# 0                       0.00                  92.26
# 1                       6.11                  87.67
# 2                       6.36                  82.68
# 3                       6.77                  90.71
# 4                      15.72                  82.40
# 5                       2.65                  94.65
# 6                       0.00                 100.00
# 7                       0.00                   0.00
# 8                       6.58                  95.55
# 9                       5.80                  80.93
#
#    tasa_aprobacion_transicion  tasa_aprobacion_primaria  \
# 0                        0.00                     96.73
# 1                        0.00                     87.90
# 2                        3.33                     84.64
# 3                        0.57                     94.12
# 4                        0.00                     89.63
# 5                        0.00                     92.84
# 6                        0.00                    100.00
# 7                        0.00                      0.00
# 8                        0.00                     98.11
# 9                        0.00                     80.92
#
#    tasa_aprobacion_secundaria  tasa_aprobacion_media  tasa_reprobacion_total  \
# 0                       83.49                  93.88                    6.55
# 1                       84.50                  92.98                    6.78
# 2                       79.51                  87.50                    9.47
# 3                       84.91                  89.93                    5.34
# 4                       69.00                  78.18                    9.24
# 5                       97.35                  93.41                    0.00
# 6                        0.00                   0.00                    0.00
# 7                        0.00                   0.00                    0.00
# 8                       93.42                  80.00                    0.00
# 9                       75.36                  87.89                   13.26
#
#    tasa_reprobacion_transicion  tasa_reprobacion_primaria  \
# 0                         0.00                       1.96
# 1                         0.00                       7.11
# 2                         3.33                       6.93
# 3                         0.57                       4.04
# 4                         0.00                       7.32
# 5                         0.00                       0.00
# 6                         0.00                       0.00
# 7                         0.00                       0.00
# 8                         0.00                       0.00
# 9                         0.00                      12.96
#
#    tasa_reprobacion_secundaria  tasa_reprobacion_media  tasa_repitencia_total  \
# 0                        16.51                    2.04                   9.52
# 1                         9.39                    1.75                   9.34
# 2                        14.13                    7.81                   8.65
# 3                         8.33                    4.60                  16.18
# 4                        15.28                    7.27                   9.24
# 5                         0.00                    0.00                  23.21
# 6                         0.00                    0.00                  21.58
# 7                         0.00                    0.00                   0.00
# 8                         0.00                    0.00                  12.33
# 9                        18.84                    8.81                  11.18
#
#    tasa_repitencia_transicion  tasa_repitencia_primaria  \
# 0                        0.00                     10.46
# 1                        6.95                     11.84
# 2                        6.67                      9.04
# 3                        7.75                     21.04
# 4                        2.86                      7.62
# 5                       25.86                     30.30
# 6                       13.33                     22.29
# 7                        0.00                      0.00
# 8                        3.13                     19.50
# 9                        0.82                     13.25
#
#    tasa_repitencia_secundaria  tasa_repitencia_media  index  poblacion
# 0                       13.76                   2.04      0     2841.0
# 1                        8.48                   3.16      1    16984.0
# 2                       10.25                   1.54      1     7947.0
# 3                       13.84                   7.18      3    34037.0
# 4                       14.85                   3.64      3     3497.0
# 5                       14.25                   6.59      3     4698.0
# 6                        0.00                   0.00      3     2543.0
# 7                        0.00                   0.00      3      802.0
# 8                        3.95                   4.00      3     1200.0
# 9                       10.45                   6.39      9    22218.0

# %%
## verificar cruce

pd.read_sql_query("""
SELECT COUNT(*) AS total_nulls
FROM educacion_final
WHERE poblacion IS NULL;
""", conn)
# Out:
#    total_nulls
# 0            0

# %%
educacion_final = pd.read_sql_query("SELECT * FROM educacion_final;", conn)
educacion_final.head(3)
# Out:
#    anio codigo_municipio nombre_municipio codigo_departamento  \
# 0  2023            05004         Abriaquí                  05
# 1  2023            95025       El Retorno                  95
# 2  2023            95200       Miraflores                  95
#
#   nombre_departamento  poblacion_5_16  total_matriculados  \
# 0           Antioquia           503.0            31497.86
# 1            Guaviare          4438.0           236412.26
# 2            Guaviare          2014.0            65495.28
#
#    tasa_matriculacion_5_16  cobertura_neta_total  cobertura_neta_transicion  \
# 0                    62.62                 62.62                      44.19
# 1                    53.27                 53.27                      33.91
# 2                    32.52                 32.52                      17.58
#
#    cobertura_neta_primaria  cobertura_neta_secundaria  cobertura_neta_media  \
# 0                    63.33                      51.53                 40.23
# 1                    48.89                      44.90                 21.30
# 2                    25.33                      26.43                 10.75
#
#    cobertura_bruta_total  cobertura_bruta_transicion  \
# 0                  66.80                       58.14
# 1                  62.98                       54.20
# 2                  38.58                       36.36
#
#    cobertura_bruta_primaria  cobertura_bruta_secundaria  \
# 0                     72.86                       66.87
# 1                     65.19                       69.60
# 2                     37.28                       46.10
#
#    cobertura_bruta_media  tasa_desercion_total  tasa_desercion_primaria  \
# 0                  56.32                  1.19                     1.31
# 1                  48.54                  5.56                     4.99
# 2                  26.16                  7.85                     8.43
#
#    tasa_desercion_secundaria  tasa_aprobacion_total  \
# 0                       0.00                  92.26
# 1                       6.11                  87.67
# 2                       6.36                  82.68
#
#    tasa_aprobacion_transicion  tasa_aprobacion_primaria  \
# 0                        0.00                     96.73
# 1                        0.00                     87.90
# 2                        3.33                     84.64
#
#    tasa_aprobacion_secundaria  tasa_aprobacion_media  tasa_reprobacion_total  \
# 0                       83.49                  93.88                    6.55
# 1                       84.50                  92.98                    6.78
# 2                       79.51                  87.50                    9.47
#
#    tasa_reprobacion_transicion  tasa_reprobacion_primaria  \
# 0                         0.00                       1.96
# 1                         0.00                       7.11
# 2                         3.33                       6.93
#
#    tasa_reprobacion_secundaria  tasa_reprobacion_media  tasa_repitencia_total  \
# 0                        16.51                    2.04                   9.52
# 1                         9.39                    1.75                   9.34
# 2                        14.13                    7.81                   8.65
#
#    tasa_repitencia_transicion  tasa_repitencia_primaria  \
# 0                        0.00                     10.46
# 1                        6.95                     11.84
# 2                        6.67                      9.04
#
#    tasa_repitencia_secundaria  tasa_repitencia_media  index  poblacion
# 0                       13.76                   2.04      0     2841.0
# 1                        8.48                   3.16      1    16984.0
# 2                       10.25                   1.54      1     7947.0

# %% [markdown]
# ### Clase 25 de junio
#
# Con la información georreferenciada se podrá:
#
# - Visualizar en un mapa: identificar en qué regiones del país están ubicados los municipios con baja cobertura neta. Esto permite ver si hay patrones en zonas rurales, apartadas o de difícil acceso.
#
# - Analizar patrones regionales: por ejemplo, explorar si los municipios de la Amazonía tienen menores tasas de matriculación o si la deserción escolar es más alta en zonas montañosas o costeras.
#
#
# Se utilizó la base de datos de georreferenciación oficial del DANE, disponible en el siguiente enlace:
#
# [DIVIPOLA - Códigos de municipios geolocalizados](https://www.datos.gov.co/Mapas-Nacionales/DIVIPOLA-C-digos-municipios-geolocalizados/vafm-j2df/about_data)
#
# Esta base incluye la latitud y longitud de cada municipio de Colombia, lo que permite integrar coordenadas geográficas a la información educativa que tenemos.

# %%
## importar datos

geo = pd.read_csv('../Datos/DIVIPOLA_geolocalizados.csv')
geo.head(3)
# Out:
#    COD_DPTO   NOM_DPTO  COD_MPIO   NOM_MPIO       TIPO   LATITUD   LONGITUD  \
# 0         5  ANTIOQUIA      5001   MEDELLÍN  Municipio  6.257590 -75.611031
# 1         5  ANTIOQUIA      5002  ABEJORRAL  Municipio  5.803728 -75.438474
# 2         5  ANTIOQUIA      5004   ABRIAQUÍ  Municipio  6.627569 -76.085978
#
#                       Geo Municipio
# 0  POINT (-75.61103107 6.257590259)
# 1  POINT (-75.43847353 5.803728154)
# 2  POINT (-76.08597756 6.627569378)

# %%
geo.groupby(['COD_DPTO', 'NOM_DPTO']).size().reset_index(name='conteo_municipios') ## cuenta cuantas filas hay en cada grupo(municipio)
# Out:
#     COD_DPTO                                           NOM_DPTO  \
# 0          5                                          ANTIOQUIA
# 1          8                                          ATLÁNTICO
# 2         11                                       BOGOTÁ, D.C.
# 3         13                                            BOLÍVAR
# 4         15                                             BOYACÁ
# 5         17                                             CALDAS
# 6         18                                            CAQUETÁ
# 7         19                                              CAUCA
# 8         20                                              CESAR
# 9         23                                            CÓRDOBA
# 10        25                                       CUNDINAMARCA
# 11        27                                              CHOCÓ
# 12        41                                              HUILA
# 13        44                                         LA GUAJIRA
# 14        47                                          MAGDALENA
# 15        50                                               META
# 16        52                                             NARIÑO
# 17        54                                 NORTE DE SANTANDER
# 18        63                                            QUINDÍO
# 19        66                                          RISARALDA
# 20        68                                          SANTANDER
# 21        70                                              SUCRE
# 22        73                                             TOLIMA
# 23        76                                    VALLE DEL CAUCA
# 24        81                                             ARAUCA
# 25        85                                           CASANARE
# 26        86                                           PUTUMAYO
# 27        88  ARCHIPIÉLAGO DE SAN ANDRÉS, PROVIDENCIA Y SANT...
# 28        91                                           AMAZONAS
# 29        94                                            GUAINÍA
# 30        95                                           GUAVIARE
# 31        97                                             VAUPÉS
# 32        99                                            VICHADA
#
#     conteo_municipios
# 0                 125
# 1                  23
# 2                   1
# 3                  46
# 4                 123
# 5                  27
# 6                  16
# 7                  42
# 8                  25
# 9                  30
# 10                116
# 11                 30
# 12                 37
# 13                 15
# 14                 30
# 15                 29
# 16                 64
# 17                 40
# 18                 12
# 19                 14
# 20                 87
# 21                 26
# 22                 47
# 23                 42
# 24                  7
# 25                 19
# 26                 13
# 27                  2
# 28                 11
# 29                  8
# 30                  4
# 31                  6
# 32                  4

# %%
## formato correcto para hacer el cruce

educacion_final['codigo_municipio'] = educacion_final['codigo_municipio'].astype(str).str.zfill(5) ## rellena con ceros hasta tener 5 caracteres
educacion_final['codigo_departamento'] = educacion_final['codigo_departamento'].astype(str).str.zfill(2) ## rellena con ceros hasta tener 2 caracteres

geo['COD_MPIO'] = geo['COD_MPIO'].astype(str).str.zfill(5)
geo['COD_DPTO'] = geo['COD_DPTO'].astype(str).str.zfill(2)

# %%
## hacer la union
educacion_geo = pd.merge(
    educacion_final,
    geo[['COD_DPTO', 'COD_MPIO', 'LATITUD', 'LONGITUD']],
    left_on=['codigo_departamento', 'codigo_municipio'],
    right_on=['COD_DPTO', 'COD_MPIO'],
    how='left'
)

educacion_geo.drop(columns=['COD_DPTO', 'COD_MPIO'], inplace=True) ## eliminar columnas extra del mergew
educacion_geo.head(3)
# Out:
#    anio codigo_municipio nombre_municipio codigo_departamento  \
# 0  2023            05004         Abriaquí                  05
# 1  2023            95025       El Retorno                  95
# 2  2023            95200       Miraflores                  95
#
#   nombre_departamento  poblacion_5_16  total_matriculados  \
# 0           Antioquia           503.0            31497.86
# 1            Guaviare          4438.0           236412.26
# 2            Guaviare          2014.0            65495.28
#
#    tasa_matriculacion_5_16  cobertura_neta_total  cobertura_neta_transicion  \
# 0                    62.62                 62.62                      44.19
# 1                    53.27                 53.27                      33.91
# 2                    32.52                 32.52                      17.58
#
#    cobertura_neta_primaria  cobertura_neta_secundaria  cobertura_neta_media  \
# 0                    63.33                      51.53                 40.23
# 1                    48.89                      44.90                 21.30
# 2                    25.33                      26.43                 10.75
#
#    cobertura_bruta_total  cobertura_bruta_transicion  \
# 0                  66.80                       58.14
# 1                  62.98                       54.20
# 2                  38.58                       36.36
#
#    cobertura_bruta_primaria  cobertura_bruta_secundaria  \
# 0                     72.86                       66.87
# 1                     65.19                       69.60
# 2                     37.28                       46.10
#
#    cobertura_bruta_media  tasa_desercion_total  tasa_desercion_primaria  \
# 0                  56.32                  1.19                     1.31
# 1                  48.54                  5.56                     4.99
# 2                  26.16                  7.85                     8.43
#
#    tasa_desercion_secundaria  tasa_aprobacion_total  \
# 0                       0.00                  92.26
# 1                       6.11                  87.67
# 2                       6.36                  82.68
#
#    tasa_aprobacion_transicion  tasa_aprobacion_primaria  \
# 0                        0.00                     96.73
# 1                        0.00                     87.90
# 2                        3.33                     84.64
#
#    tasa_aprobacion_secundaria  tasa_aprobacion_media  tasa_reprobacion_total  \
# 0                       83.49                  93.88                    6.55
# 1                       84.50                  92.98                    6.78
# 2                       79.51                  87.50                    9.47
#
#    tasa_reprobacion_transicion  tasa_reprobacion_primaria  \
# 0                         0.00                       1.96
# 1                         0.00                       7.11
# 2                         3.33                       6.93
#
#    tasa_reprobacion_secundaria  tasa_reprobacion_media  tasa_repitencia_total  \
# 0                        16.51                    2.04                   9.52
# 1                         9.39                    1.75                   9.34
# 2                        14.13                    7.81                   8.65
#
#    tasa_repitencia_transicion  tasa_repitencia_primaria  \
# 0                        0.00                     10.46
# 1                        6.95                     11.84
# 2                        6.67                      9.04
#
#    tasa_repitencia_secundaria  tasa_repitencia_media  index  poblacion  \
# 0                       13.76                   2.04      0     2841.0
# 1                        8.48                   3.16      1    16984.0
# 2                       10.25                   1.54      1     7947.0
#
#     LATITUD   LONGITUD
# 0  6.627569 -76.085978
# 1  2.143447 -72.243649
# 2  1.363975 -72.018110

# %%
educacion_geo[["LATITUD", "LONGITUD"]].isna().sum()
# Out:
# LATITUD     9
# LONGITUD    9
# dtype: int64

# %%
faltantes_geo = educacion_geo[educacion_geo["LATITUD"].isna() | educacion_geo["LONGITUD"].isna()][
    ["nombre_departamento","codigo_departamento", "codigo_municipio", "nombre_municipio"]
]
faltantes_geo

## Mapiripama del depto Guainía no esta en la info de divipola
# Out:
#       nombre_departamento codigo_departamento codigo_municipio  \
# 4505              Guainía                  94            94663
# 5608              Guainía                  94            94663
# 6753              Guainía                  94            94663
# 8953              Guainía                  94            94663
# 8981              Guainía                  94            94663
# 10138             Guainía                  94            94663
# 11233             Guainía                  94            94663
# 12347             Guainía                  94            94663
# 13484             Guainía                  94            94663
#
#       nombre_municipio
# 4505        Mapiripana
# 5608        Mapiripana
# 6753        Mapiripana
# 8953        Mapiripana
# 8981        Mapiripana
# 10138       Mapiripana
# 11233       Mapiripana
# 12347       Mapiripana
# 13484       Mapiripana

# %% [markdown]
# Mapiripama del depto Guainía no esta en la info de divipola

# %%
educacion_final[educacion_final['codigo_municipio'] == '94663']
# Out:
#        anio codigo_municipio nombre_municipio codigo_departamento  \
# 4505   2019            94663       Mapiripana                  94
# 5608   2018            94663       Mapiripana                  94
# 6753   2017            94663       Mapiripana                  94
# 8953   2016            94663       Mapiripana                  94
# 8981   2015            94663       Mapiripana                  94
# 10138  2014            94663       Mapiripana                  94
# 11233  2013            94663       Mapiripana                  94
# 12347  2012            94663       Mapiripana                  94
# 13484  2011            94663       Mapiripana                  94
#
#       nombre_departamento  poblacion_5_16  total_matriculados  \
# 4505              Guainía           388.0            20800.68
# 5608              Guainía           385.0            10760.75
# 6753              Guainía           800.0            21600.00
# 8953              Guainía           815.0            20864.00
# 8981              Guainía           841.0            23800.30
# 10138             Guainía           860.0            26703.00
# 11233             Guainía           888.0            29597.04
# 12347             Guainía           904.0            31802.72
# 13484             Guainía           944.0            29500.00
#
#        tasa_matriculacion_5_16  cobertura_neta_total  \
# 4505                     53.61                 53.61
# 5608                     27.95                 56.62
# 6753                     27.00                 27.00
# 8953                     25.60                 25.64
# 8981                     28.30                 86.40
# 10138                    31.05                 73.55
# 11233                    33.33                 33.30
# 12347                    35.18                 35.20
# 13484                    31.25                 31.30
#
#        cobertura_neta_transicion  cobertura_neta_primaria  \
# 4505                       44.74                    54.22
# 5608                       38.46                    50.91
# 6753                       26.67                    20.64
# 8953                        6.67                    25.94
# 8981                        6.58                    82.84
# 10138                      42.42                    59.01
# 11233                      12.70                    29.00
# 12347                      20.20                    29.20
# 13484                      38.20                    82.84
#
#        cobertura_neta_secundaria  cobertura_neta_media  cobertura_bruta_total  \
# 4505                       25.00                  1.79                  72.42
# 5608                       36.22                  1.85                  74.55
# 6753                       10.89                  1.50                  35.50
# 8953                       12.89                  1.46                  35.46
# 8981                       12.73                  2.74                  39.12
# 10138                      25.00                 11.11                  42.21
# 11233                      16.00                  2.60                  44.00
# 12347                      16.20                  2.50                  44.00
# 13484                      16.10                 41.18                  40.90
#
#        cobertura_bruta_transicion  cobertura_bruta_primaria  \
# 4505                        57.89                     79.52
# 5608                        56.41                     76.97
# 6753                        34.67                     38.08
# 8953                        24.00                     37.75
# 8981                        19.74                     41.19
# 10138                       45.21                     45.74
# 11233                       35.20                     51.00
# 12347                       42.90                     58.40
# 13484                       56.60                     55.70
#
#        cobertura_bruta_secundaria  cobertura_bruta_media  \
# 4505                        71.09                  64.29
# 5608                        85.83                  53.70
# 6753                        39.11                  22.56
# 8953                        42.97                  21.90
# 8981                        48.31                  27.40
# 10138                       43.51                  30.00
# 11233                       43.50                  33.30
# 12347                       44.10                  13.20
# 13484                       41.20                  75.25
#
#        tasa_desercion_total  tasa_desercion_primaria  \
# 4505                   7.83                     5.30
# 5608                  12.54                     6.30
# 6753                   8.45                     9.16
# 8953                  11.42                     9.92
# 8981                   4.56                     2.32
# 10138                  4.41                     2.48
# 11233                  4.60                     2.76
# 12347                 10.30                    11.39
# 13484                  3.13                     2.32
#
#        tasa_desercion_secundaria  tasa_aprobacion_total  \
# 4505                        8.79                  65.84
# 5608                       19.27                  54.36
# 6753                        6.19                  71.13
# 8953                       10.91                  67.47
# 8981                        8.53                  72.34
# 10138                       7.26                  95.59
# 11233                       6.02                  84.65
# 12347                       8.63                  73.62
# 13484                      12.32                  74.18
#
#        tasa_aprobacion_transicion  tasa_aprobacion_primaria  \
# 4505                         0.00                     48.48
# 5608                         0.00                     41.73
# 6753                         0.00                     60.31
# 8953                         0.00                     60.31
# 8981                         0.00                     74.48
# 10138                        0.00                     97.52
# 11233                        4.00                     82.32
# 12347                        2.78                     61.88
# 13484                        4.65                     64.48
#
#        tasa_aprobacion_secundaria  tasa_aprobacion_media  \
# 4505                        78.02                  83.33
# 5608                        55.96                  75.86
# 6753                        76.29                  90.00
# 8953                        69.09                  83.33
# 8981                        68.22                  67.50
# 10138                       92.74                  97.78
# 11233                       83.46                  92.31
# 12347                       85.61                  95.24
# 13484                       83.33                  93.29
#
#        tasa_reprobacion_total  tasa_reprobacion_transicion  \
# 4505                    26.33                         0.00
# 5608                    33.10                         0.00
# 6753                    20.42                         0.00
# 8953                    21.11                         0.00
# 8981                     4.52                         0.00
# 10138                    0.00                         0.00
# 11233                   10.74                         4.00
# 12347                    4.52                         2.78
# 13484                   12.91                         4.65
#
#        tasa_reprobacion_primaria  tasa_reprobacion_secundaria  \
# 4505                       46.21                        13.19
# 5608                       51.97                        24.77
# 6753                       30.53                        17.53
# 8953                       29.77                        20.00
# 8981                        3.33                         6.16
# 10138                       0.00                         0.00
# 11233                       3.33                        10.53
# 12347                       3.33                         5.76
# 13484                       3.33                         4.35
#
#        tasa_reprobacion_media  tasa_repitencia_total  \
# 4505                     2.78                  34.52
# 5608                     6.90                  18.12
# 6753                     3.33                   0.00
# 8953                     0.00                   0.00
# 8981                     3.11                   2.43
# 10138                    0.00                   0.00
# 11233                    0.00                   1.02
# 12347                    4.76                   0.00
# 13484                    0.00                   0.55
#
#        tasa_repitencia_transicion  tasa_repitencia_primaria  \
# 4505                         9.09                     50.76
# 5608                         9.09                     29.92
# 6753                         0.00                      0.00
# 8953                         0.00                      0.00
# 8981                         0.00                      2.07
# 10138                        0.00                      0.00
# 11233                        0.00                      0.55
# 12347                        0.00                      0.00
# 13484                        0.00                      1.09
#
#        tasa_repitencia_secundaria  tasa_repitencia_media  index  poblacion
# 4505                        24.18                  16.67     14     1048.0
# 5608                        11.01                   0.00     14     1022.0
# 6753                         0.00                   0.00     14     1032.0
# 8953                         0.00                   0.00     14     1051.0
# 8981                         2.33                   0.00     14     1038.0
# 10138                        0.00                   0.00     14     1018.0
# 11233                        2.26                   0.00     14     1030.0
# 12347                        0.00                   0.00     14     1042.0
# 13484                        0.00                   0.87     14     1047.0

# %%
geo[geo['COD_MPIO'] == '94663'] 
## no esta en geo
# Out:
# Empty DataFrame
# Columns: [COD_DPTO, NOM_DPTO, COD_MPIO, NOM_MPIO, TIPO, LATITUD, LONGITUD, Geo Municipio]
# Index: []

# %% [markdown]
# ## Inclusión manual de coordenadas Mapiripana
#
# Para el municipio de Mapiripana (94663) del departamento de Guainía, no se encontraron registros georreferenciados en la base oficial de DIVIPOLA.
#
# Por esta razón, se optó por agregar manualmente las coordenadas geográficas utilizando como fuente confiable el sitio:
#
# [municipio.com.co - Mapiripana](https://www.municipio.com.co/corregimiento-departamental-mapiripana.html)
#
# Según esta fuente, las coordenadas son:
#
# - **Latitud**: 2.617
# - **Longitud**: -70.533
#
# Estas coordenadas se incorporarán a la base `geo` para poder unir correctamente los datos educativos de Mapiripana con la información geográfica disponible.

# %%
# coordenadas
lat_mapiripana = 2.753444
lon_mapiripana = -69.531509

# Añadir latitud y longitud solo a las filas correspondientes
educacion_geo.loc[educacion_geo['codigo_municipio'] == '94663', 'LATITUD'] = lat_mapiripana
educacion_geo.loc[educacion_geo['codigo_municipio'] == '94663', 'LONGITUD'] = lon_mapiripana

# %%
educacion_geo[["LATITUD", "LONGITUD"]].isna().sum()
# Out:
# LATITUD     0
# LONGITUD    0
# dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(8,6))
sns.scatterplot(
    data=educacion_geo,
    x='tasa_matriculacion_5_16',
    y='cobertura_neta_total',
    hue='nombre_departamento',
    alpha=0.7
)
plt.title('Relación entre Tasa de Matriculación y Cobertura Neta Total')
plt.xlabel('Tasa de Matriculación 5-16')
plt.ylabel('Cobertura Neta Total')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### modelo estrella

# %%
educacion_geo['anio'] = educacion_geo['anio'].astype(int) ## convertir año a entero

# %%
dim_tiempo = educacion_geo[['anio']].drop_duplicates().copy()
dim_tiempo['decada'] = (dim_tiempo['anio'] // 10) * 10
dim_tiempo['quinquenio'] = pd.cut(
    dim_tiempo['anio'],
    bins=[2010, 2015, 2020, 2025],
    labels=['2011-2015', '2016-2020', '2021-2024']
)

# %%
dim_tiempo.head(3)
# Out:
#       anio  decada quinquenio
# 0     2023    2020  2021-2024
# 1121  2022    2020  2021-2024
# 2242  2021    2020  2021-2024

# %%
dim_municipio = educacion_geo[[
    'codigo_municipio', 'nombre_municipio',
    'codigo_departamento', 'LATITUD', 'LONGITUD'
]].drop_duplicates().copy()

# %%
dim_municipio.head(3)
# Out:
#   codigo_municipio nombre_municipio codigo_departamento   LATITUD   LONGITUD
# 0            05004         Abriaquí                  05  6.627569 -76.085978
# 1            95025       El Retorno                  95  2.143447 -72.243649
# 2            95200       Miraflores                  95  1.363975 -72.018110

# %%
dim_departamento = educacion_geo[[
    'codigo_departamento', 'nombre_departamento'
]].drop_duplicates().copy()

# %%
dim_departamento.head(3)
# Out:
#   codigo_departamento nombre_departamento
# 0                  05           Antioquia
# 1                  95            Guaviare
# 3                  97              Vaupés

# %%
hechos_educacion = educacion_geo.drop(columns=[
    'nombre_municipio', 'nombre_departamento', 'LATITUD', 'LONGITUD'
])

# %%
hechos_educacion.head(3)
# Out:
#    anio codigo_municipio codigo_departamento  poblacion_5_16  \
# 0  2023            05004                  05           503.0
# 1  2023            95025                  95          4438.0
# 2  2023            95200                  95          2014.0
#
#    total_matriculados  tasa_matriculacion_5_16  cobertura_neta_total  \
# 0            31497.86                    62.62                 62.62
# 1           236412.26                    53.27                 53.27
# 2            65495.28                    32.52                 32.52
#
#    cobertura_neta_transicion  cobertura_neta_primaria  \
# 0                      44.19                    63.33
# 1                      33.91                    48.89
# 2                      17.58                    25.33
#
#    cobertura_neta_secundaria  cobertura_neta_media  cobertura_bruta_total  \
# 0                      51.53                 40.23                  66.80
# 1                      44.90                 21.30                  62.98
# 2                      26.43                 10.75                  38.58
#
#    cobertura_bruta_transicion  cobertura_bruta_primaria  \
# 0                       58.14                     72.86
# 1                       54.20                     65.19
# 2                       36.36                     37.28
#
#    cobertura_bruta_secundaria  cobertura_bruta_media  tasa_desercion_total  \
# 0                       66.87                  56.32                  1.19
# 1                       69.60                  48.54                  5.56
# 2                       46.10                  26.16                  7.85
#
#    tasa_desercion_primaria  tasa_desercion_secundaria  tasa_aprobacion_total  \
# 0                     1.31                       0.00                  92.26
# 1                     4.99                       6.11                  87.67
# 2                     8.43                       6.36                  82.68
#
#    tasa_aprobacion_transicion  tasa_aprobacion_primaria  \
# 0                        0.00                     96.73
# 1                        0.00                     87.90
# 2                        3.33                     84.64
#
#    tasa_aprobacion_secundaria  tasa_aprobacion_media  tasa_reprobacion_total  \
# 0                       83.49                  93.88                    6.55
# 1                       84.50                  92.98                    6.78
# 2                       79.51                  87.50                    9.47
#
#    tasa_reprobacion_transicion  tasa_reprobacion_primaria  \
# 0                         0.00                       1.96
# 1                         0.00                       7.11
# 2                         3.33                       6.93
#
#    tasa_reprobacion_secundaria  tasa_reprobacion_media  tasa_repitencia_total  \
# 0                        16.51                    2.04                   9.52
# 1                         9.39                    1.75                   9.34
# 2                        14.13                    7.81                   8.65
#
#    tasa_repitencia_transicion  tasa_repitencia_primaria  \
# 0                        0.00                     10.46
# 1                        6.95                     11.84
# 2                        6.67                      9.04
#
#    tasa_repitencia_secundaria  tasa_repitencia_media  index  poblacion
# 0                       13.76                   2.04      0     2841.0
# 1                        8.48                   3.16      1    16984.0
# 2                       10.25                   1.54      1     7947.0

# %%
dim_tiempo.to_csv("../Datos/dim_tiempo.csv", index=False)
dim_municipio.to_csv("../Datos/dim_municipio.csv", index=False)
dim_departamento.to_csv("../Datos/dim_departamento.csv", index=False)
hechos_educacion.to_csv("../Datos/hechos_educacion.csv", index=False)
